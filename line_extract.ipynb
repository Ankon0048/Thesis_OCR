# %%
# !pip install opencv-python
# !pip install numpy
# !pip install matplotlib
# Out:
# Requirement already satisfied: opencv-python in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (4.11.0.86)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from opencv-python) (2.1.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: numpy in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (2.1.1)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: matplotlib in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (3.10.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python313\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # Without Watershed

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def calculate_projection_profile_and_crop_lines(image_path, output_dir):
    # Load the image in grayscale
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Check if image is loaded
    if image is None:
        print("Error: Unable to load image.")
        return

    # Binarize the image using Otsu's threshold
    _, binary_image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Calculate the horizontal projection profile
    horizontal_projection = np.sum(binary_image, axis=1)

    # Normalize the profile for better thresholding
    threshold = 0.1 * np.max(horizontal_projection)

    # Apply watershed algorithm for the below task
    # Find row ranges for each line
    line_ranges = []
    is_in_line = False
    start_row = 0
    for row, value in enumerate(horizontal_projection):
        if value > threshold:
            if not is_in_line:
                start_row = row
                is_in_line = True
        else:
            if is_in_line:
                end_row = row
                line_ranges.append((start_row,end_row))
                is_in_line = False


    if(len(line_ranges)!=0):
      line_ranges[0] = (max(0,line_ranges[0][0]-10),line_ranges[0][1])
      line_ranges[-1] = (line_ranges[-1][0],min(image.shape[1],line_ranges[-1][1]+7))

    for i in range(1,len(line_ranges)):
        temp = (line_ranges[i-1][1] + line_ranges[i][0]) // 2
        line_ranges[i-1] = (line_ranges[i-1][0], temp)
        line_ranges[i] = (temp, line_ranges[i][1])

    # Crop and save each detected line
    cropped_lines = []
    for idx, (start, end) in enumerate(line_ranges):
        cropped_line = image[start:end, :]  # Crop the original grayscale image
        cropped_lines.append(cropped_line)
        # Save the cropped line as an image
        # print(cropped_line)
        output_path = f"{output_dir}/line_{idx + 1}.png"
        cv2.imwrite(output_path, cropped_line)
        print(f"Saved cropped line {idx + 1} to {output_path}")

    # Plot the projection profile and detected lines
    plt.figure(figsize=(10, 6))
    plt.subplot(2, 1, 1)
    plt.imshow(binary_image, cmap='gray')
    plt.title("Binarized Image")
    plt.axis('off')

    plt.subplot(2, 1, 2)
    plt.plot(horizontal_projection, range(binary_image.shape[0]), color='b')
    plt.gca().invert_yaxis()
    plt.title("Horizontal Projection Profile")
    plt.xlabel("Sum of Pixel Intensities")
    plt.ylabel("Row Index")

    # # Mark the detected line ranges
    # for start, end in line_ranges:
    #     plt.axhline(y=start, color='r', linestyle='--', xmin=0.05, xmax=0.95, label="Line Start")
    #     plt.axhline(y=end, color='g', linestyle='--', xmin=0.05, xmax=0.95, label="Line End")
    # plt.legend(["Projection Profile", "Line Start", "Line End"], loc="upper right")
    # plt.show()

    # Print detected line ranges
    print("Detected Line Ranges (Start Row, End Row):")
    for start, end in line_ranges:
        print(f"Line: {start} to {end}")

# Example usage
# Replace the paths below with your image path and output directory
# calculate_projection_profile_and_crop_lines(image_path, output_dir)

# %% [markdown]
# # Watershed

# %%
import cv2
import numpy as np
import os
import matplotlib.pyplot as plt

def calculate_lines_watershed(image_path, output_dir):
    # 1) Read image in grayscale
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print("Error: Unable to load image.")
        return

    # 2) Binarize (Otsu) and invert so text is white, background is black
    #    (Watershed often expects the foreground to be bright on dark background)
    _, binary_inv = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # 3) Morphological dilation to connect text within the same line
    #    Increase the kernel width if your lines are spaced out more
    kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (80, 1))
    dilated = cv2.dilate(binary_inv, kernel, iterations=1)

    # 4) Distance transform to help separate regions
    dist_transform = cv2.distanceTransform(dilated, cv2.DIST_L2, 5)
    dist_max = dist_transform.max()

    # 5) Threshold the distance map to get sure foreground
    #    Adjust the factor (e.g., 0.3 * dist_max) if lines are merging or splitting incorrectly
    _, sure_fg = cv2.threshold(dist_transform, 0.3 * dist_max, 255, 0)
    sure_fg = np.uint8(sure_fg)

    # 6) Unknown region is what's left between sure foreground and original binarized area
    #    (the watershed will decide how to label these)
    unknown = cv2.subtract(dilated, sure_fg)

    # 7) Label the sure foreground
    num_markers, markers = cv2.connectedComponents(sure_fg)
    # Make sure the background is labeled as 1 instead of 0
    markers = markers + 1
    # Label the unknown region as 0 so that watershed can fill it
    markers[unknown == 255] = 0

    # 8) Convert original image to color so we can visualize watershed boundaries
    image_color = cv2.cvtColor(image, cv2.COLOR_GRAY2BGR)

    # 9) Apply the watershed algorithm
    markers = cv2.watershed(image_color, markers)
    # Mark watershed boundaries in red on the color image (for visualization)
    image_color[markers == -1] = [0, 0, 255]

    # 10) Each distinct marker > 1 now corresponds to a text “line” region
    #     We’ll find bounding boxes for each marker and save them
    if not os.path.exists(output_dir):
        os.makedirs(output_dir, exist_ok=True)

    line_id = 1
    for marker_value in range(2, num_markers + 1):
        # Extract pixels belonging to the current marker
        mask = np.uint8(markers == marker_value)

        # If the mask is too small, skip it (noise or spurious region)
        if cv2.countNonZero(mask) < 10:
            continue

        # Find bounding box of the current marker
        x, y, w, h = cv2.boundingRect(mask)

        # Crop that region from the original grayscale image
        cropped_line = image[y:y+h, x:x+w]

        # Save the cropped line
        output_path = os.path.join(output_dir, f"line_{line_id}.png")
        cv2.imwrite(output_path, cropped_line)
        print(f"Saved cropped line {line_id} to {output_path}")
        line_id += 1

    # 11) (Optional) Show final results side by side
    #     Left: Original binarized (inverted) image
    #     Right: Watershed boundaries in red
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 2, 1)
    plt.title("Binarized (Inverted)")
    plt.imshow(binary_inv, cmap='gray')
    plt.axis('off')

    plt.subplot(1, 2, 2)
    plt.title("Watershed Boundaries")
    plt.imshow(image_color[..., ::-1])  # Convert BGR to RGB for matplotlib
    plt.axis('off')
    plt.show()

    print("Watershed-based line segmentation complete!")

# Example usage:
# calculate_lines_watershed(image_path, output_dir)

# %% [markdown]
# # With watershed and horizontal projection profile

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def calculate_projection_profile_and_crop_lines_with_watershed(image_path, output_dir):
    # Load the image in grayscale
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

    # Check if image is loaded
    if image is None:
        print("Error: Unable to load image.")
        return

    # Binarize the image using Otsu's threshold
    _, binary_image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Calculate the horizontal projection profile
    horizontal_projection = np.sum(binary_image, axis=1)

    # Normalize the profile for better thresholding
    threshold = 0.1 * np.max(horizontal_projection)

        # Convert horizontal projection to 2D grayscale image
    proj_img = horizontal_projection.astype(np.uint8)
    proj_img = cv2.normalize(proj_img, None, 0, 255, cv2.NORM_MINMAX)
    proj_img = 255 - proj_img  # Invert so lines become basins
    proj_img_2d = np.repeat(proj_img[:, np.newaxis], 100, axis=1)  # make it 2D image-like

    # Threshold to get sure foreground (lines)
    _, thresh = cv2.threshold(proj_img_2d, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Noise removal
    kernel = np.ones((3, 3), np.uint8)
    opening = cv2.morphologyEx(thresh, cv2.MORPH_OPEN, kernel, iterations=2)

    # Sure background area
    sure_bg = cv2.dilate(opening, kernel, iterations=3)

    # Sure foreground area
    dist_transform = cv2.distanceTransform(opening, cv2.DIST_L2, 5)
    _, sure_fg = cv2.threshold(dist_transform, 0.5 * dist_transform.max(), 255, 0)

    # Unknown region
    sure_fg = np.uint8(sure_fg)
    unknown = cv2.subtract(sure_bg, sure_fg)

    # Marker labelling
    num_labels, markers = cv2.connectedComponents(sure_fg)
    markers = markers + 1
    markers[unknown == 255] = 0

    # Apply watershed
    proj_img_color = cv2.cvtColor(proj_img_2d, cv2.COLOR_GRAY2BGR)
    cv2.watershed(proj_img_color, markers)

    # Extract line ranges from marker labels
    line_ranges = []
    for label in range(2, np.max(markers) + 1):  # skip background
        rows = np.where(markers[:, 50] == label)[0]  # Check the center column
        if rows.size > 0:
            start_row, end_row = np.min(rows), np.max(rows)
            if end_row - start_row > 5:  # filter small noise
                line_ranges.append((start_row, end_row))


        # Visualization
    plt.figure(figsize=(14, 10))

    # 1. Original Binarized Image
    plt.subplot(2, 2, 1)
    plt.imshow(binary_image, cmap='gray')
    plt.title("Binarized Image")
    plt.axis('off')

    # 2. Horizontal Projection Profile
    plt.subplot(2, 2, 2)
    plt.plot(horizontal_projection, range(binary_image.shape[0]), color='blue')
    plt.gca().invert_yaxis()
    plt.title("Horizontal Projection Profile")
    plt.xlabel("Sum of Pixel Intensities")
    plt.ylabel("Row Index")

    # 3. 2D Image from Projection
    plt.subplot(2, 2, 3)
    plt.imshow(proj_img_2d, cmap='gray', aspect='auto')
    plt.title("Projection Image for Watershed")
    plt.axis('off')

    # 4. Watershed Markers Visualized
    marker_vis = np.zeros_like(proj_img_2d)
    for label in range(2, np.max(markers) + 1):
        marker_vis[markers == label] = 255
    plt.subplot(2, 2, 4)
    plt.imshow(marker_vis, cmap='jet', aspect='auto')
    plt.title("Watershed Markers on Projection Image")
    plt.axis('off')

    plt.tight_layout()
    plt.show()



    if(len(line_ranges)!=0):
      line_ranges[0] = (max(0,line_ranges[0][0]-10),line_ranges[0][1])
      line_ranges[-1] = (line_ranges[-1][0],min(image.shape[1],line_ranges[-1][1]+7))

    for i in range(1,len(line_ranges)):
        temp = (line_ranges[i-1][1] + line_ranges[i][0]) // 2
        line_ranges[i-1] = (line_ranges[i-1][0], temp)
        line_ranges[i] = (temp, line_ranges[i][1])

    # Crop and save each detected line
    cropped_lines = []
    for idx, (start, end) in enumerate(line_ranges):
        cropped_line = image[start:end, :]  # Crop the original grayscale image
        cropped_lines.append(cropped_line)
        # Save the cropped line as an image
        # print(cropped_line)
        output_path = f"{output_dir}/line_{idx + 1}.png"
        cv2.imwrite(output_path, cropped_line)
        print(f"Saved cropped line {idx + 1} to {output_path}")

    # Plot the projection profile and detected lines
    plt.figure(figsize=(10, 6))
    plt.subplot(2, 1, 1)
    plt.imshow(binary_image, cmap='gray')
    plt.title("Binarized Image")
    plt.axis('off')

    plt.subplot(2, 1, 2)
    plt.plot(horizontal_projection, range(binary_image.shape[0]), color='b')
    plt.gca().invert_yaxis()
    plt.title("Horizontal Projection Profile")
    plt.xlabel("Sum of Pixel Intensities")
    plt.ylabel("Row Index")

    # # Mark the detected line ranges
    # for start, end in line_ranges:
    #     plt.axhline(y=start, color='r', linestyle='--', xmin=0.05, xmax=0.95, label="Line Start")
    #     plt.axhline(y=end, color='g', linestyle='--', xmin=0.05, xmax=0.95, label="Line End")
    # plt.legend(["Projection Profile", "Line Start", "Line End"], loc="upper right")
    # plt.show()

    # Print detected line ranges
    print("Detected Line Ranges (Start Row, End Row):")
    for start, end in line_ranges:
        print(f"Line: {start} to {end}")

# Example usage
# Replace the paths below with your image path and output directory
# calculate_projection_profile_and_crop_lines(image_path, output_dir)

# %% [markdown]
# # Testing

# %% [markdown]
# starting from 10,000 is IAM dataset

# %%
image_path = 'D://Thesis//Mass_Line_Extraction//input_images//'
output_dir = 'D://Thesis//Mass_Line_Extraction//output_images//'
output_dir_without = 'D://Thesis//Mass_Line_Extraction//output_images_without//'
output_dir_with_water_horizon = 'D://Thesis//Mass_Line_Extraction//output_with_water_horizon//'

# %% [markdown]
# Line_Extraction_code

# %%
import os
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import find_peaks

def testing_calculate_projection_profile_and_crop_lines(image_path, output_dir, cnt):
    try:
        # Validate cnt
        if not isinstance(cnt, int):
            raise ValueError("Counter 'cnt' must be an integer.")

        # Validate output_dir, create if it doesn't exist
        if not os.path.exists(output_dir):
            os.makedirs(output_dir)
            print(f"Output directory '{output_dir}' did not exist and was created.")

        # Load the image in grayscale
        image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

        # Check if image is loaded
        if image is None:
            raise FileNotFoundError(f"Error: Unable to load image from {image_path}")

        # Binarize the image using Otsu's threshold
        _, binary_image = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

        # Calculate the horizontal projection profile
        horizontal_projection = np.sum(binary_image, axis=1)

        # Normalize the profile for better thresholding
        threshold = 0.1 * np.max(horizontal_projection)

        # Find row ranges for each line
        line_ranges = []
        is_in_line = False
        start_row = 0
        for row, value in enumerate(horizontal_projection):
            if value > threshold:
                if not is_in_line:
                    start_row = row
                    is_in_line = True
            else:
                if is_in_line:
                    end_row = row
                    line_ranges.append((start_row, end_row))
                    is_in_line = False

        # Adjust first and last line boundaries slightly
        if len(line_ranges) != 0:
            line_ranges[0] = (max(0, line_ranges[0][0] - 10), line_ranges[0][1])
            line_ranges[-1] = (line_ranges[-1][0], min(image.shape[0], line_ranges[-1][1] + 7))

        # Refine line boundaries by averaging gaps
        for i in range(1, len(line_ranges)):
            temp = (line_ranges[i - 1][1] + line_ranges[i][0]) // 2
            line_ranges[i - 1] = (line_ranges[i - 1][0], temp)
            line_ranges[i] = (temp, line_ranges[i][1])

        # Crop and save each detected line
        cropped_lines = []
        for idx, (start, end) in enumerate(line_ranges):
            cropped_line = image[start:end, :]  # Crop the original grayscale image
            cropped_lines.append(cropped_line)
            output_path = os.path.join(output_dir, f"line_{cnt}.png")

            success = cv2.imwrite(output_path, cropped_line)
            if not success:
                print(f"Warning: Failed to save cropped line {cnt} to {output_path}")
            else:
                print(f"Saved cropped line {cnt} to {output_path}")
            cnt += 1

        return cnt

    except Exception as e:
        print(f"An error occurred: {e}")
        return cnt  # Return current cnt even if something went wrong

# %% [markdown]
# extracting lines from custom dataset

# %%
import os

image_path = 'D://Thesis//Mass_Line_Extraction//input_images//'
output_dir_without = 'D://Thesis//Mass_Line_Extraction//output_images_without//'
# List all files in the directory
files = os.listdir(image_path)
cnt = 0
# Loop through the files and print the full path
for file in files:
    full_path = os.path.join(image_path, file)
    # cv2.imread(full_path)
    cnt = testing_calculate_projection_profile_and_crop_lines(full_path, output_dir_without, cnt)
# Out:
# Saved cropped line 0 to D://Thesis//Mass_Line_Extraction//output_images_without//line_0.png
# Saved cropped line 1 to D://Thesis//Mass_Line_Extraction//output_images_without//line_1.png
# Saved cropped line 2 to D://Thesis//Mass_Line_Extraction//output_images_without//line_2.png
# Saved cropped line 3 to D://Thesis//Mass_Line_Extraction//output_images_without//line_3.png
# Saved cropped line 4 to D://Thesis//Mass_Line_Extraction//output_images_without//line_4.png
# Saved cropped line 5 to D://Thesis//Mass_Line_Extraction//output_images_without//line_5.png
# Saved cropped line 6 to D://Thesis//Mass_Line_Extraction//output_images_without//line_6.png
# Saved cropped line 7 to D://Thesis//Mass_Line_Extraction//output_images_without//line_7.png
# Saved cropped line 8 to D://Thesis//Mass_Line_Extraction//output_images_without//line_8.png
# Saved cropped line 9 to D://Thesis//Mass_Line_Extraction//output_images_without//line_9.png
# Saved cropped line 10 to D://Thesis//Mass_Line_Extraction//output_images_without//line_10.png
# Saved cropped line 11 to D://Thesis//Mass_Line_Extraction//output_images_without//line_11.png
# Saved cropped line 12 to D://Thesis//Mass_Line_Extraction//output_images_without//line_12.png
# Saved cropped line 13 to D://Thesis//Mass_Line_Extraction//output_images_without//line_13.png
# Saved cropped line 14 to D://Thesis//Mass_Line_Extraction//output_images_without//line_14.png
# Saved cropped line 15 to D://Thesis//Mass_Line_Extraction//output_images_without//line_15.png
# Saved cropped line 16 to D://Thesis//Mass_Line_Extraction//output_images_without//line_16.png
# Saved cropped line 17 to D://Thesis//Mass_Line_Extraction//output_images_without//line_17.png
# Saved cropped line 18 to D://Thesis//Mass_Line_Extraction//output_images_without//line_18.png
# Saved cropped line 19 to D://Thesis//Mass_Line_Extraction//output_images_without//line_19.png
# Saved cropped line 20 to D://Thesis//Mass_Line_Extraction//output_images_without//line_20.png
# Saved cropped line 21 to D://Thesis//Mass_Line_Extraction//output_images_without//line_21.png
# Saved cropped line 22 to D://Thesis//Mass_Line_Extraction//output_images_without//line_22.png
# Saved cropped line 23 to D://Thesis//Mass_Line_Extraction//output_images_without//line_23.png
# Saved cropped line 24 to D://Thesis//Mass_Line_Extraction//output_images_without//line_24.png
# Saved cropped line 25 to D://Thesis//Mass_Line_Extraction//output_images_without//line_25.png
# Saved cropped line 26 to D://Thesis//Mass_Line_Extraction//output_images_without//line_26.png
# Saved cropped line 27 to D://Thesis//Mass_Line_Extraction//output_images_without//line_27.png
# Saved cropped line 28 to D://Thesis//Mass_Line_Extraction//output_images_without//line_28.png
# Saved cropped line 29 to D://Thesis//Mass_Line_Extraction//output_images_without//line_29.png
# Saved cropped line 30 to D://Thesis//Mass_Line_Extraction//output_images_without//line_30.png
# Saved cropped line 31 to D://Thesis//Mass_Line_Extraction//output_images_without//line_31.png
# Saved cropped line 32 to D://Thesis//Mass_Line_Extraction//output_images_without//line_32.png
# Saved cropped line 33 to D://Thesis//Mass_Line_Extraction//output_images_without//line_33.png
# Saved cropped line 34 to D://Thesis//Mass_Line_Extraction//output_images_without//line_34.png
# Saved cropped line 35 to D://Thesis//Mass_Line_Extraction//output_images_without//line_35.png
# Saved cropped line 36 to D://Thesis//Mass_Line_Extraction//output_images_without//line_36.png
# Saved cropped line 37 to D://Thesis//Mass_Line_Extraction//output_images_without//line_37.png
# Saved cropped line 38 to D://Thesis//Mass_Line_Extraction//output_images_without//line_38.png
# Saved cropped line 39 to D://Thesis//Mass_Line_Extraction//output_images_without//line_39.png
# Saved cropped line 40 to D://Thesis//Mass_Line_Extraction//output_images_without//line_40.png
# Saved cropped line 41 to D://Thesis//Mass_Line_Extraction//output_images_without//line_41.png
# Saved cropped line 42 to D://Thesis//Mass_Line_Extraction//output_images_without//line_42.png
# Saved cropped line 43 to D://Thesis//Mass_Line_Extraction//output_images_without//line_43.png
# Saved cropped line 44 to D://Thesis//Mass_Line_Extraction//output_images_without//line_44.png
# Saved cropped line 45 to D://Thesis//Mass_Line_Extraction//output_images_without//line_45.png
# Saved cropped line 46 to D://Thesis//Mass_Line_Extraction//output_images_without//line_46.png
# Saved cropped line 47 to D://Thesis//Mass_Line_Extraction//output_images_without//line_47.png
# Saved cropped line 48 to D://Thesis//Mass_Line_Extraction//output_images_without//line_48.png
# Saved cropped line 49 to D://Thesis//Mass_Line_Extraction//output_images_without//line_49.png
# Saved cropped line 50 to D://Thesis//Mass_Line_Extraction//output_images_without//line_50.png
# Saved cropped line 51 to D://Thesis//Mass_Line_Extraction//output_images_without//line_51.png
# Saved cropped line 52 to D://Thesis//Mass_Line_Extraction//output_images_without//line_52.png
# Saved cropped line 53 to D://Thesis//Mass_Line_Extraction//output_images_without//line_53.png
# Saved cropped line 54 to D://Thesis//Mass_Line_Extraction//output_images_without//line_54.png
# Saved cropped line 55 to D://Thesis//Mass_Line_Extraction//output_images_without//line_55.png
# Saved cropped line 56 to D://Thesis//Mass_Line_Extraction//output_images_without//line_56.png
# Saved cropped line 57 to D://Thesis//Mass_Line_Extraction//output_images_without//line_57.png
# Saved cropped line 58 to D://Thesis//Mass_Line_Extraction//output_images_without//line_58.png
# Saved cropped line 59 to D://Thesis//Mass_Line_Extraction//output_images_without//line_59.png
# Saved cropped line 60 to D://Thesis//Mass_Line_Extraction//output_images_without//line_60.png
# Saved cropped line 61 to D://Thesis//Mass_Line_Extraction//output_images_without//line_61.png
# Saved cropped line 62 to D://Thesis//Mass_Line_Extraction//output_images_without//line_62.png
# Saved cropped line 63 to D://Thesis//Mass_Line_Extraction//output_images_without//line_63.png
# Saved cropped line 64 to D://Thesis//Mass_Line_Extraction//output_images_without//line_64.png
# Saved cropped line 65 to D://Thesis//Mass_Line_Extraction//output_images_without//line_65.png
# Saved cropped line 66 to D://Thesis//Mass_Line_Extraction//output_images_without//line_66.png
# Saved cropped line 67 to D://Thesis//Mass_Line_Extraction//output_images_without//line_67.png
# Saved cropped line 68 to D://Thesis//Mass_Line_Extraction//output_images_without//line_68.png
# Saved cropped line 69 to D://Thesis//Mass_Line_Extraction//output_images_without//line_69.png
# Saved cropped line 70 to D://Thesis//Mass_Line_Extraction//output_images_without//line_70.png
# Saved cropped line 71 to D://Thesis//Mass_Line_Extraction//output_images_without//line_71.png
# Saved cropped line 72 to D://Thesis//Mass_Line_Extraction//output_images_without//line_72.png
# Saved cropped line 73 to D://Thesis//Mass_Line_Extraction//output_images_without//line_73.png
# Saved cropped line 74 to D://Thesis//Mass_Line_Extraction//output_images_without//line_74.png
# Saved cropped line 75 to D://Thesis//Mass_Line_Extraction//output_images_without//line_75.png
# Saved cropped line 76 to D://Thesis//Mass_Line_Extraction//output_images_without//line_76.png
# Saved cropped line 77 to D://Thesis//Mass_Line_Extraction//output_images_without//line_77.png
# Saved cropped line 78 to D://Thesis//Mass_Line_Extraction//output_images_without//line_78.png
# Saved cropped line 79 to D://Thesis//Mass_Line_Extraction//output_images_without//line_79.png
# Saved cropped line 80 to D://Thesis//Mass_Line_Extraction//output_images_without//line_80.png
# Saved cropped line 81 to D://Thesis//Mass_Line_Extraction//output_images_without//line_81.png
# Saved cropped line 82 to D://Thesis//Mass_Line_Extraction//output_images_without//line_82.png
# Saved cropped line 83 to D://Thesis//Mass_Line_Extraction//output_images_without//line_83.png
# Saved cropped line 84 to D://Thesis//Mass_Line_Extraction//output_images_without//line_84.png
# Saved cropped line 85 to D://Thesis//Mass_Line_Extraction//output_images_without//line_85.png
# Saved cropped line 86 to D://Thesis//Mass_Line_Extraction//output_images_without//line_86.png
# Saved cropped line 87 to D://Thesis//Mass_Line_Extraction//output_images_without//line_87.png
# Saved cropped line 88 to D://Thesis//Mass_Line_Extraction//output_images_without//line_88.png
# Saved cropped line 89 to D://Thesis//Mass_Line_Extraction//output_images_without//line_89.png
# Saved cropped line 90 to D://Thesis//Mass_Line_Extraction//output_images_without//line_90.png
# Saved cropped line 91 to D://Thesis//Mass_Line_Extraction//output_images_without//line_91.png
# Saved cropped line 92 to D://Thesis//Mass_Line_Extraction//output_images_without//line_92.png
# Saved cropped line 93 to D://Thesis//Mass_Line_Extraction//output_images_without//line_93.png
# Saved cropped line 94 to D://Thesis//Mass_Line_Extraction//output_images_without//line_94.png
# Saved cropped line 95 to D://Thesis//Mass_Line_Extraction//output_images_without//line_95.png
# Saved cropped line 96 to D://Thesis//Mass_Line_Extraction//output_images_without//line_96.png
# Saved cropped line 97 to D://Thesis//Mass_Line_Extraction//output_images_without//line_97.png
# Saved cropped line 98 to D://Thesis//Mass_Line_Extraction//output_images_without//line_98.png
# Saved cropped line 99 to D://Thesis//Mass_Line_Extraction//output_images_without//line_99.png
# Saved cropped line 100 to D://Thesis//Mass_Line_Extraction//output_images_without//line_100.png
# Saved cropped line 101 to D://Thesis//Mass_Line_Extraction//output_images_without//line_101.png
# Saved cropped line 102 to D://Thesis//Mass_Line_Extraction//output_images_without//line_102.png
# Saved cropped line 103 to D://Thesis//Mass_Line_Extraction//output_images_without//line_103.png
# Saved cropped line 104 to D://Thesis//Mass_Line_Extraction//output_images_without//line_104.png
# Saved cropped line 105 to D://Thesis//Mass_Line_Extraction//output_images_without//line_105.png
# Saved cropped line 106 to D://Thesis//Mass_Line_Extraction//output_images_without//line_106.png
# Saved cropped line 107 to D://Thesis//Mass_Line_Extraction//output_images_without//line_107.png
# Saved cropped line 108 to D://Thesis//Mass_Line_Extraction//output_images_without//line_108.png
# Saved cropped line 109 to D://Thesis//Mass_Line_Extraction//output_images_without//line_109.png
# Saved cropped line 110 to D://Thesis//Mass_Line_Extraction//output_images_without//line_110.png
# Saved cropped line 111 to D://Thesis//Mass_Line_Extraction//output_images_without//line_111.png
# Saved cropped line 112 to D://Thesis//Mass_Line_Extraction//output_images_without//line_112.png
# Saved cropped line 113 to D://Thesis//Mass_Line_Extraction//output_images_without//line_113.png
# Saved cropped line 114 to D://Thesis//Mass_Line_Extraction//output_images_without//line_114.png
# Saved cropped line 115 to D://Thesis//Mass_Line_Extraction//output_images_without//line_115.png
# Saved cropped line 116 to D://Thesis//Mass_Line_Extraction//output_images_without//line_116.png
# Saved cropped line 117 to D://Thesis//Mass_Line_Extraction//output_images_without//line_117.png
# Saved cropped line 118 to D://Thesis//Mass_Line_Extraction//output_images_without//line_118.png
# Saved cropped line 119 to D://Thesis//Mass_Line_Extraction//output_images_without//line_119.png
# Saved cropped line 120 to D://Thesis//Mass_Line_Extraction//output_images_without//line_120.png
# Saved cropped line 121 to D://Thesis//Mass_Line_Extraction//output_images_without//line_121.png
# Saved cropped line 122 to D://Thesis//Mass_Line_Extraction//output_images_without//line_122.png
# Saved cropped line 123 to D://Thesis//Mass_Line_Extraction//output_images_without//line_123.png
# Saved cropped line 124 to D://Thesis//Mass_Line_Extraction//output_images_without//line_124.png
# Saved cropped line 125 to D://Thesis//Mass_Line_Extraction//output_images_without//line_125.png
# Saved cropped line 126 to D://Thesis//Mass_Line_Extraction//output_images_without//line_126.png
# Saved cropped line 127 to D://Thesis//Mass_Line_Extraction//output_images_without//line_127.png
# Saved cropped line 128 to D://Thesis//Mass_Line_Extraction//output_images_without//line_128.png
# Saved cropped line 129 to D://Thesis//Mass_Line_Extraction//output_images_without//line_129.png
# Saved cropped line 130 to D://Thesis//Mass_Line_Extraction//output_images_without//line_130.png
# Saved cropped line 131 to D://Thesis//Mass_Line_Extraction//output_images_without//line_131.png
# Saved cropped line 132 to D://Thesis//Mass_Line_Extraction//output_images_without//line_132.png
# Saved cropped line 133 to D://Thesis//Mass_Line_Extraction//output_images_without//line_133.png
# Saved cropped line 134 to D://Thesis//Mass_Line_Extraction//output_images_without//line_134.png
# Saved cropped line 135 to D://Thesis//Mass_Line_Extraction//output_images_without//line_135.png
# Saved cropped line 136 to D://Thesis//Mass_Line_Extraction//output_images_without//line_136.png
# Saved cropped line 137 to D://Thesis//Mass_Line_Extraction//output_images_without//line_137.png
# Saved cropped line 138 to D://Thesis//Mass_Line_Extraction//output_images_without//line_138.png
# Saved cropped line 139 to D://Thesis//Mass_Line_Extraction//output_images_without//line_139.png
# Saved cropped line 140 to D://Thesis//Mass_Line_Extraction//output_images_without//line_140.png
# Saved cropped line 141 to D://Thesis//Mass_Line_Extraction//output_images_without//line_141.png
# Saved cropped line 142 to D://Thesis//Mass_Line_Extraction//output_images_without//line_142.png
# Saved cropped line 143 to D://Thesis//Mass_Line_Extraction//output_images_without//line_143.png
# Saved cropped line 144 to D://Thesis//Mass_Line_Extraction//output_images_without//line_144.png
# Saved cropped line 145 to D://Thesis//Mass_Line_Extraction//output_images_without//line_145.png
# Saved cropped line 146 to D://Thesis//Mass_Line_Extraction//output_images_without//line_146.png
# Saved cropped line 147 to D://Thesis//Mass_Line_Extraction//output_images_without//line_147.png
# Saved cropped line 148 to D://Thesis//Mass_Line_Extraction//output_images_without//line_148.png
# Saved cropped line 149 to D://Thesis//Mass_Line_Extraction//output_images_without//line_149.png
# Saved cropped line 150 to D://Thesis//Mass_Line_Extraction//output_images_without//line_150.png
# Saved cropped line 151 to D://Thesis//Mass_Line_Extraction//output_images_without//line_151.png
# Saved cropped line 152 to D://Thesis//Mass_Line_Extraction//output_images_without//line_152.png
# Saved cropped line 153 to D://Thesis//Mass_Line_Extraction//output_images_without//line_153.png
# Saved cropped line 154 to D://Thesis//Mass_Line_Extraction//output_images_without//line_154.png
# Saved cropped line 155 to D://Thesis//Mass_Line_Extraction//output_images_without//line_155.png
# Saved cropped line 156 to D://Thesis//Mass_Line_Extraction//output_images_without//line_156.png
# Saved cropped line 157 to D://Thesis//Mass_Line_Extraction//output_images_without//line_157.png
# Saved cropped line 158 to D://Thesis//Mass_Line_Extraction//output_images_without//line_158.png
# Saved cropped line 159 to D://Thesis//Mass_Line_Extraction//output_images_without//line_159.png
# Saved cropped line 160 to D://Thesis//Mass_Line_Extraction//output_images_without//line_160.png
# Saved cropped line 161 to D://Thesis//Mass_Line_Extraction//output_images_without//line_161.png
# Saved cropped line 162 to D://Thesis//Mass_Line_Extraction//output_images_without//line_162.png
# Saved cropped line 163 to D://Thesis//Mass_Line_Extraction//output_images_without//line_163.png
# Saved cropped line 164 to D://Thesis//Mass_Line_Extraction//output_images_without//line_164.png
# Saved cropped line 165 to D://Thesis//Mass_Line_Extraction//output_images_without//line_165.png
# Saved cropped line 166 to D://Thesis//Mass_Line_Extraction//output_images_without//line_166.png
# Saved cropped line 167 to D://Thesis//Mass_Line_Extraction//output_images_without//line_167.png
# Saved cropped line 168 to D://Thesis//Mass_Line_Extraction//output_images_without//line_168.png
# Saved cropped line 169 to D://Thesis//Mass_Line_Extraction//output_images_without//line_169.png
# Saved cropped line 170 to D://Thesis//Mass_Line_Extraction//output_images_without//line_170.png
# Saved cropped line 171 to D://Thesis//Mass_Line_Extraction//output_images_without//line_171.png
# Saved cropped line 172 to D://Thesis//Mass_Line_Extraction//output_images_without//line_172.png
# Saved cropped line 173 to D://Thesis//Mass_Line_Extraction//output_images_without//line_173.png
# Saved cropped line 174 to D://Thesis//Mass_Line_Extraction//output_images_without//line_174.png
# Saved cropped line 175 to D://Thesis//Mass_Line_Extraction//output_images_without//line_175.png
# Saved cropped line 176 to D://Thesis//Mass_Line_Extraction//output_images_without//line_176.png
# Saved cropped line 177 to D://Thesis//Mass_Line_Extraction//output_images_without//line_177.png
# Saved cropped line 178 to D://Thesis//Mass_Line_Extraction//output_images_without//line_178.png
# Saved cropped line 179 to D://Thesis//Mass_Line_Extraction//output_images_without//line_179.png
# Saved cropped line 180 to D://Thesis//Mass_Line_Extraction//output_images_without//line_180.png
# Saved cropped line 181 to D://Thesis//Mass_Line_Extraction//output_images_without//line_181.png
# Saved cropped line 182 to D://Thesis//Mass_Line_Extraction//output_images_without//line_182.png
# Saved cropped line 183 to D://Thesis//Mass_Line_Extraction//output_images_without//line_183.png
# Saved cropped line 184 to D://Thesis//Mass_Line_Extraction//output_images_without//line_184.png
# Saved cropped line 185 to D://Thesis//Mass_Line_Extraction//output_images_without//line_185.png
# Saved cropped line 186 to D://Thesis//Mass_Line_Extraction//output_images_without//line_186.png
# Saved cropped line 187 to D://Thesis//Mass_Line_Extraction//output_images_without//line_187.png
# Saved cropped line 188 to D://Thesis//Mass_Line_Extraction//output_images_without//line_188.png
# Saved cropped line 189 to D://Thesis//Mass_Line_Extraction//output_images_without//line_189.png
# Saved cropped line 190 to D://Thesis//Mass_Line_Extraction//output_images_without//line_190.png
# Saved cropped line 191 to D://Thesis//Mass_Line_Extraction//output_images_without//line_191.png
# Saved cropped line 192 to D://Thesis//Mass_Line_Extraction//output_images_without//line_192.png
# Saved cropped line 193 to D://Thesis//Mass_Line_Extraction//output_images_without//line_193.png
# Saved cropped line 194 to D://Thesis//Mass_Line_Extraction//output_images_without//line_194.png
# Saved cropped line 195 to D://Thesis//Mass_Line_Extraction//output_images_without//line_195.png
# Saved cropped line 196 to D://Thesis//Mass_Line_Extraction//output_images_without//line_196.png
# Saved cropped line 197 to D://Thesis//Mass_Line_Extraction//output_images_without//line_197.png
# Saved cropped line 198 to D://Thesis//Mass_Line_Extraction//output_images_without//line_198.png
# Saved cropped line 199 to D://Thesis//Mass_Line_Extraction//output_images_without//line_199.png
# Saved cropped line 200 to D://Thesis//Mass_Line_Extraction//output_images_without//line_200.png
# Saved cropped line 201 to D://Thesis//Mass_Line_Extraction//output_images_without//line_201.png
# Saved cropped line 202 to D://Thesis//Mass_Line_Extraction//output_images_without//line_202.png
# Saved cropped line 203 to D://Thesis//Mass_Line_Extraction//output_images_without//line_203.png
# Saved cropped line 204 to D://Thesis//Mass_Line_Extraction//output_images_without//line_204.png
# Saved cropped line 205 to D://Thesis//Mass_Line_Extraction//output_images_without//line_205.png
# Saved cropped line 206 to D://Thesis//Mass_Line_Extraction//output_images_without//line_206.png
# Saved cropped line 207 to D://Thesis//Mass_Line_Extraction//output_images_without//line_207.png
# Saved cropped line 208 to D://Thesis//Mass_Line_Extraction//output_images_without//line_208.png
# Saved cropped line 209 to D://Thesis//Mass_Line_Extraction//output_images_without//line_209.png
# Saved cropped line 210 to D://Thesis//Mass_Line_Extraction//output_images_without//line_210.png
# Saved cropped line 211 to D://Thesis//Mass_Line_Extraction//output_images_without//line_211.png
# Saved cropped line 212 to D://Thesis//Mass_Line_Extraction//output_images_without//line_212.png
# Saved cropped line 213 to D://Thesis//Mass_Line_Extraction//output_images_without//line_213.png
# Saved cropped line 214 to D://Thesis//Mass_Line_Extraction//output_images_without//line_214.png
# Saved cropped line 215 to D://Thesis//Mass_Line_Extraction//output_images_without//line_215.png
# Saved cropped line 216 to D://Thesis//Mass_Line_Extraction//output_images_without//line_216.png
# Saved cropped line 217 to D://Thesis//Mass_Line_Extraction//output_images_without//line_217.png
# Saved cropped line 218 to D://Thesis//Mass_Line_Extraction//output_images_without//line_218.png
# Saved cropped line 219 to D://Thesis//Mass_Line_Extraction//output_images_without//line_219.png
# Saved cropped line 220 to D://Thesis//Mass_Line_Extraction//output_images_without//line_220.png
# Saved cropped line 221 to D://Thesis//Mass_Line_Extraction//output_images_without//line_221.png
# Saved cropped line 222 to D://Thesis//Mass_Line_Extraction//output_images_without//line_222.png
# Saved cropped line 223 to D://Thesis//Mass_Line_Extraction//output_images_without//line_223.png
# Saved cropped line 224 to D://Thesis//Mass_Line_Extraction//output_images_without//line_224.png
# Saved cropped line 225 to D://Thesis//Mass_Line_Extraction//output_images_without//line_225.png
# Saved cropped line 226 to D://Thesis//Mass_Line_Extraction//output_images_without//line_226.png
# Saved cropped line 227 to D://Thesis//Mass_Line_Extraction//output_images_without//line_227.png
# Saved cropped line 228 to D://Thesis//Mass_Line_Extraction//output_images_without//line_228.png
# Saved cropped line 229 to D://Thesis//Mass_Line_Extraction//output_images_without//line_229.png
# Saved cropped line 230 to D://Thesis//Mass_Line_Extraction//output_images_without//line_230.png
# Saved cropped line 231 to D://Thesis//Mass_Line_Extraction//output_images_without//line_231.png
# Saved cropped line 232 to D://Thesis//Mass_Line_Extraction//output_images_without//line_232.png
# Saved cropped line 233 to D://Thesis//Mass_Line_Extraction//output_images_without//line_233.png
# Saved cropped line 234 to D://Thesis//Mass_Line_Extraction//output_images_without//line_234.png
# Saved cropped line 235 to D://Thesis//Mass_Line_Extraction//output_images_without//line_235.png
# Saved cropped line 236 to D://Thesis//Mass_Line_Extraction//output_images_without//line_236.png
# Saved cropped line 237 to D://Thesis//Mass_Line_Extraction//output_images_without//line_237.png
# Saved cropped line 238 to D://Thesis//Mass_Line_Extraction//output_images_without//line_238.png
# Saved cropped line 239 to D://Thesis//Mass_Line_Extraction//output_images_without//line_239.png
# Saved cropped line 240 to D://Thesis//Mass_Line_Extraction//output_images_without//line_240.png
# Saved cropped line 241 to D://Thesis//Mass_Line_Extraction//output_images_without//line_241.png
# Saved cropped line 242 to D://Thesis//Mass_Line_Extraction//output_images_without//line_242.png
# Saved cropped line 243 to D://Thesis//Mass_Line_Extraction//output_images_without//line_243.png
# Saved cropped line 244 to D://Thesis//Mass_Line_Extraction//output_images_without//line_244.png
# Saved cropped line 245 to D://Thesis//Mass_Line_Extraction//output_images_without//line_245.png
# Saved cropped line 246 to D://Thesis//Mass_Line_Extraction//output_images_without//line_246.png
# Saved cropped line 247 to D://Thesis//Mass_Line_Extraction//output_images_without//line_247.png
# Saved cropped line 248 to D://Thesis//Mass_Line_Extraction//output_images_without//line_248.png
# Saved cropped line 249 to D://Thesis//Mass_Line_Extraction//output_images_without//line_249.png
# Saved cropped line 250 to D://Thesis//Mass_Line_Extraction//output_images_without//line_250.png
# Saved cropped line 251 to D://Thesis//Mass_Line_Extraction//output_images_without//line_251.png
# Saved cropped line 252 to D://Thesis//Mass_Line_Extraction//output_images_without//line_252.png
# Saved cropped line 253 to D://Thesis//Mass_Line_Extraction//output_images_without//line_253.png
# Saved cropped line 254 to D://Thesis//Mass_Line_Extraction//output_images_without//line_254.png
# Saved cropped line 255 to D://Thesis//Mass_Line_Extraction//output_images_without//line_255.png
# Saved cropped line 256 to D://Thesis//Mass_Line_Extraction//output_images_without//line_256.png
# Saved cropped line 257 to D://Thesis//Mass_Line_Extraction//output_images_without//line_257.png
# Saved cropped line 258 to D://Thesis//Mass_Line_Extraction//output_images_without//line_258.png
# Saved cropped line 259 to D://Thesis//Mass_Line_Extraction//output_images_without//line_259.png
# Saved cropped line 260 to D://Thesis//Mass_Line_Extraction//output_images_without//line_260.png
# Saved cropped line 261 to D://Thesis//Mass_Line_Extraction//output_images_without//line_261.png
# Saved cropped line 262 to D://Thesis//Mass_Line_Extraction//output_images_without//line_262.png
# Saved cropped line 263 to D://Thesis//Mass_Line_Extraction//output_images_without//line_263.png
# Saved cropped line 264 to D://Thesis//Mass_Line_Extraction//output_images_without//line_264.png
# Saved cropped line 265 to D://Thesis//Mass_Line_Extraction//output_images_without//line_265.png
# Saved cropped line 266 to D://Thesis//Mass_Line_Extraction//output_images_without//line_266.png
# Saved cropped line 267 to D://Thesis//Mass_Line_Extraction//output_images_without//line_267.png
# Saved cropped line 268 to D://Thesis//Mass_Line_Extraction//output_images_without//line_268.png
# Saved cropped line 269 to D://Thesis//Mass_Line_Extraction//output_images_without//line_269.png
# Saved cropped line 270 to D://Thesis//Mass_Line_Extraction//output_images_without//line_270.png
# Saved cropped line 271 to D://Thesis//Mass_Line_Extraction//output_images_without//line_271.png
# Saved cropped line 272 to D://Thesis//Mass_Line_Extraction//output_images_without//line_272.png
# Saved cropped line 273 to D://Thesis//Mass_Line_Extraction//output_images_without//line_273.png
# Saved cropped line 274 to D://Thesis//Mass_Line_Extraction//output_images_without//line_274.png
# Saved cropped line 275 to D://Thesis//Mass_Line_Extraction//output_images_without//line_275.png
# Saved cropped line 276 to D://Thesis//Mass_Line_Extraction//output_images_without//line_276.png
# Saved cropped line 277 to D://Thesis//Mass_Line_Extraction//output_images_without//line_277.png
# Saved cropped line 278 to D://Thesis//Mass_Line_Extraction//output_images_without//line_278.png
# Saved cropped line 279 to D://Thesis//Mass_Line_Extraction//output_images_without//line_279.png
# Saved cropped line 280 to D://Thesis//Mass_Line_Extraction//output_images_without//line_280.png
# Saved cropped line 281 to D://Thesis//Mass_Line_Extraction//output_images_without//line_281.png
# Saved cropped line 282 to D://Thesis//Mass_Line_Extraction//output_images_without//line_282.png
# Saved cropped line 283 to D://Thesis//Mass_Line_Extraction//output_images_without//line_283.png
# Saved cropped line 284 to D://Thesis//Mass_Line_Extraction//output_images_without//line_284.png
# Saved cropped line 285 to D://Thesis//Mass_Line_Extraction//output_images_without//line_285.png
# Saved cropped line 286 to D://Thesis//Mass_Line_Extraction//output_images_without//line_286.png
# Saved cropped line 287 to D://Thesis//Mass_Line_Extraction//output_images_without//line_287.png
# Saved cropped line 288 to D://Thesis//Mass_Line_Extraction//output_images_without//line_288.png
# Saved cropped line 289 to D://Thesis//Mass_Line_Extraction//output_images_without//line_289.png
# Saved cropped line 290 to D://Thesis//Mass_Line_Extraction//output_images_without//line_290.png
# Saved cropped line 291 to D://Thesis//Mass_Line_Extraction//output_images_without//line_291.png
# Saved cropped line 292 to D://Thesis//Mass_Line_Extraction//output_images_without//line_292.png
# Saved cropped line 293 to D://Thesis//Mass_Line_Extraction//output_images_without//line_293.png
# Saved cropped line 294 to D://Thesis//Mass_Line_Extraction//output_images_without//line_294.png
# Saved cropped line 295 to D://Thesis//Mass_Line_Extraction//output_images_without//line_295.png
# Saved cropped line 296 to D://Thesis//Mass_Line_Extraction//output_images_without//line_296.png
# Saved cropped line 297 to D://Thesis//Mass_Line_Extraction//output_images_without//line_297.png
# Saved cropped line 298 to D://Thesis//Mass_Line_Extraction//output_images_without//line_298.png
# Saved cropped line 299 to D://Thesis//Mass_Line_Extraction//output_images_without//line_299.png
# Saved cropped line 300 to D://Thesis//Mass_Line_Extraction//output_images_without//line_300.png
# Saved cropped line 301 to D://Thesis//Mass_Line_Extraction//output_images_without//line_301.png
# Saved cropped line 302 to D://Thesis//Mass_Line_Extraction//output_images_without//line_302.png
# Saved cropped line 303 to D://Thesis//Mass_Line_Extraction//output_images_without//line_303.png
# Saved cropped line 304 to D://Thesis//Mass_Line_Extraction//output_images_without//line_304.png
# Saved cropped line 305 to D://Thesis//Mass_Line_Extraction//output_images_without//line_305.png
# Saved cropped line 306 to D://Thesis//Mass_Line_Extraction//output_images_without//line_306.png
# Saved cropped line 307 to D://Thesis//Mass_Line_Extraction//output_images_without//line_307.png
# Saved cropped line 308 to D://Thesis//Mass_Line_Extraction//output_images_without//line_308.png
# Saved cropped line 309 to D://Thesis//Mass_Line_Extraction//output_images_without//line_309.png
# Saved cropped line 310 to D://Thesis//Mass_Line_Extraction//output_images_without//line_310.png
# Saved cropped line 311 to D://Thesis//Mass_Line_Extraction//output_images_without//line_311.png
# Saved cropped line 312 to D://Thesis//Mass_Line_Extraction//output_images_without//line_312.png
# Saved cropped line 313 to D://Thesis//Mass_Line_Extraction//output_images_without//line_313.png
# Saved cropped line 314 to D://Thesis//Mass_Line_Extraction//output_images_without//line_314.png
# Saved cropped line 315 to D://Thesis//Mass_Line_Extraction//output_images_without//line_315.png
# Saved cropped line 316 to D://Thesis//Mass_Line_Extraction//output_images_without//line_316.png
# Saved cropped line 317 to D://Thesis//Mass_Line_Extraction//output_images_without//line_317.png
# Saved cropped line 318 to D://Thesis//Mass_Line_Extraction//output_images_without//line_318.png
# Saved cropped line 319 to D://Thesis//Mass_Line_Extraction//output_images_without//line_319.png
# Saved cropped line 320 to D://Thesis//Mass_Line_Extraction//output_images_without//line_320.png
# Saved cropped line 321 to D://Thesis//Mass_Line_Extraction//output_images_without//line_321.png
# Saved cropped line 322 to D://Thesis//Mass_Line_Extraction//output_images_without//line_322.png
# Saved cropped line 323 to D://Thesis//Mass_Line_Extraction//output_images_without//line_323.png
# Saved cropped line 324 to D://Thesis//Mass_Line_Extraction//output_images_without//line_324.png
# Saved cropped line 325 to D://Thesis//Mass_Line_Extraction//output_images_without//line_325.png
# Saved cropped line 326 to D://Thesis//Mass_Line_Extraction//output_images_without//line_326.png
# Saved cropped line 327 to D://Thesis//Mass_Line_Extraction//output_images_without//line_327.png
# Saved cropped line 328 to D://Thesis//Mass_Line_Extraction//output_images_without//line_328.png
# Saved cropped line 329 to D://Thesis//Mass_Line_Extraction//output_images_without//line_329.png
# Saved cropped line 330 to D://Thesis//Mass_Line_Extraction//output_images_without//line_330.png
# Saved cropped line 331 to D://Thesis//Mass_Line_Extraction//output_images_without//line_331.png
# Saved cropped line 332 to D://Thesis//Mass_Line_Extraction//output_images_without//line_332.png
# Saved cropped line 333 to D://Thesis//Mass_Line_Extraction//output_images_without//line_333.png
# Saved cropped line 334 to D://Thesis//Mass_Line_Extraction//output_images_without//line_334.png
# Saved cropped line 335 to D://Thesis//Mass_Line_Extraction//output_images_without//line_335.png
# Saved cropped line 336 to D://Thesis//Mass_Line_Extraction//output_images_without//line_336.png
# Saved cropped line 337 to D://Thesis//Mass_Line_Extraction//output_images_without//line_337.png
# Saved cropped line 338 to D://Thesis//Mass_Line_Extraction//output_images_without//line_338.png
# Saved cropped line 339 to D://Thesis//Mass_Line_Extraction//output_images_without//line_339.png
# Saved cropped line 340 to D://Thesis//Mass_Line_Extraction//output_images_without//line_340.png
# Saved cropped line 341 to D://Thesis//Mass_Line_Extraction//output_images_without//line_341.png
# Saved cropped line 342 to D://Thesis//Mass_Line_Extraction//output_images_without//line_342.png
# Saved cropped line 343 to D://Thesis//Mass_Line_Extraction//output_images_without//line_343.png
# Saved cropped line 344 to D://Thesis//Mass_Line_Extraction//output_images_without//line_344.png
# Saved cropped line 345 to D://Thesis//Mass_Line_Extraction//output_images_without//line_345.png
# Saved cropped line 346 to D://Thesis//Mass_Line_Extraction//output_images_without//line_346.png
# Saved cropped line 347 to D://Thesis//Mass_Line_Extraction//output_images_without//line_347.png
# Saved cropped line 348 to D://Thesis//Mass_Line_Extraction//output_images_without//line_348.png
# Saved cropped line 349 to D://Thesis//Mass_Line_Extraction//output_images_without//line_349.png
# Saved cropped line 350 to D://Thesis//Mass_Line_Extraction//output_images_without//line_350.png
# Saved cropped line 351 to D://Thesis//Mass_Line_Extraction//output_images_without//line_351.png
# Saved cropped line 352 to D://Thesis//Mass_Line_Extraction//output_images_without//line_352.png
# Saved cropped line 353 to D://Thesis//Mass_Line_Extraction//output_images_without//line_353.png
# Saved cropped line 354 to D://Thesis//Mass_Line_Extraction//output_images_without//line_354.png
# Saved cropped line 355 to D://Thesis//Mass_Line_Extraction//output_images_without//line_355.png
# Saved cropped line 356 to D://Thesis//Mass_Line_Extraction//output_images_without//line_356.png
# Saved cropped line 357 to D://Thesis//Mass_Line_Extraction//output_images_without//line_357.png
# Saved cropped line 358 to D://Thesis//Mass_Line_Extraction//output_images_without//line_358.png
# Saved cropped line 359 to D://Thesis//Mass_Line_Extraction//output_images_without//line_359.png
# Saved cropped line 360 to D://Thesis//Mass_Line_Extraction//output_images_without//line_360.png
# Saved cropped line 361 to D://Thesis//Mass_Line_Extraction//output_images_without//line_361.png
# Saved cropped line 362 to D://Thesis//Mass_Line_Extraction//output_images_without//line_362.png
# Saved cropped line 363 to D://Thesis//Mass_Line_Extraction//output_images_without//line_363.png
# Saved cropped line 364 to D://Thesis//Mass_Line_Extraction//output_images_without//line_364.png
# Saved cropped line 365 to D://Thesis//Mass_Line_Extraction//output_images_without//line_365.png
# Saved cropped line 366 to D://Thesis//Mass_Line_Extraction//output_images_without//line_366.png
# Saved cropped line 367 to D://Thesis//Mass_Line_Extraction//output_images_without//line_367.png
# Saved cropped line 368 to D://Thesis//Mass_Line_Extraction//output_images_without//line_368.png
# Saved cropped line 369 to D://Thesis//Mass_Line_Extraction//output_images_without//line_369.png
# Saved cropped line 370 to D://Thesis//Mass_Line_Extraction//output_images_without//line_370.png
# Saved cropped line 371 to D://Thesis//Mass_Line_Extraction//output_images_without//line_371.png
# Saved cropped line 372 to D://Thesis//Mass_Line_Extraction//output_images_without//line_372.png
# Saved cropped line 373 to D://Thesis//Mass_Line_Extraction//output_images_without//line_373.png
# Saved cropped line 374 to D://Thesis//Mass_Line_Extraction//output_images_without//line_374.png
# Saved cropped line 375 to D://Thesis//Mass_Line_Extraction//output_images_without//line_375.png
# Saved cropped line 376 to D://Thesis//Mass_Line_Extraction//output_images_without//line_376.png
# Saved cropped line 377 to D://Thesis//Mass_Line_Extraction//output_images_without//line_377.png
# Saved cropped line 378 to D://Thesis//Mass_Line_Extraction//output_images_without//line_378.png
# Saved cropped line 379 to D://Thesis//Mass_Line_Extraction//output_images_without//line_379.png
# Saved cropped line 380 to D://Thesis//Mass_Line_Extraction//output_images_without//line_380.png
# Saved cropped line 381 to D://Thesis//Mass_Line_Extraction//output_images_without//line_381.png
# Saved cropped line 382 to D://Thesis//Mass_Line_Extraction//output_images_without//line_382.png
# Saved cropped line 383 to D://Thesis//Mass_Line_Extraction//output_images_without//line_383.png
# Saved cropped line 384 to D://Thesis//Mass_Line_Extraction//output_images_without//line_384.png
# Saved cropped line 385 to D://Thesis//Mass_Line_Extraction//output_images_without//line_385.png
# Saved cropped line 386 to D://Thesis//Mass_Line_Extraction//output_images_without//line_386.png
# Saved cropped line 387 to D://Thesis//Mass_Line_Extraction//output_images_without//line_387.png
# Saved cropped line 388 to D://Thesis//Mass_Line_Extraction//output_images_without//line_388.png
# Saved cropped line 389 to D://Thesis//Mass_Line_Extraction//output_images_without//line_389.png
# Saved cropped line 390 to D://Thesis//Mass_Line_Extraction//output_images_without//line_390.png
# Saved cropped line 391 to D://Thesis//Mass_Line_Extraction//output_images_without//line_391.png
# Saved cropped line 392 to D://Thesis//Mass_Line_Extraction//output_images_without//line_392.png
# Saved cropped line 393 to D://Thesis//Mass_Line_Extraction//output_images_without//line_393.png
# Saved cropped line 394 to D://Thesis//Mass_Line_Extraction//output_images_without//line_394.png
# Saved cropped line 395 to D://Thesis//Mass_Line_Extraction//output_images_without//line_395.png
# Saved cropped line 396 to D://Thesis//Mass_Line_Extraction//output_images_without//line_396.png
# Saved cropped line 397 to D://Thesis//Mass_Line_Extraction//output_images_without//line_397.png
# Saved cropped line 398 to D://Thesis//Mass_Line_Extraction//output_images_without//line_398.png
# Saved cropped line 399 to D://Thesis//Mass_Line_Extraction//output_images_without//line_399.png
# Saved cropped line 400 to D://Thesis//Mass_Line_Extraction//output_images_without//line_400.png
# Saved cropped line 401 to D://Thesis//Mass_Line_Extraction//output_images_without//line_401.png
# Saved cropped line 402 to D://Thesis//Mass_Line_Extraction//output_images_without//line_402.png
# Saved cropped line 403 to D://Thesis//Mass_Line_Extraction//output_images_without//line_403.png
# Saved cropped line 404 to D://Thesis//Mass_Line_Extraction//output_images_without//line_404.png
# Saved cropped line 405 to D://Thesis//Mass_Line_Extraction//output_images_without//line_405.png
# Saved cropped line 406 to D://Thesis//Mass_Line_Extraction//output_images_without//line_406.png
# Saved cropped line 407 to D://Thesis//Mass_Line_Extraction//output_images_without//line_407.png
# Saved cropped line 408 to D://Thesis//Mass_Line_Extraction//output_images_without//line_408.png
# Saved cropped line 409 to D://Thesis//Mass_Line_Extraction//output_images_without//line_409.png
# Saved cropped line 410 to D://Thesis//Mass_Line_Extraction//output_images_without//line_410.png
# Saved cropped line 411 to D://Thesis//Mass_Line_Extraction//output_images_without//line_411.png
# Saved cropped line 412 to D://Thesis//Mass_Line_Extraction//output_images_without//line_412.png
# Saved cropped line 413 to D://Thesis//Mass_Line_Extraction//output_images_without//line_413.png
# Saved cropped line 414 to D://Thesis//Mass_Line_Extraction//output_images_without//line_414.png
# Saved cropped line 415 to D://Thesis//Mass_Line_Extraction//output_images_without//line_415.png
# Saved cropped line 416 to D://Thesis//Mass_Line_Extraction//output_images_without//line_416.png
# Saved cropped line 417 to D://Thesis//Mass_Line_Extraction//output_images_without//line_417.png
# Saved cropped line 418 to D://Thesis//Mass_Line_Extraction//output_images_without//line_418.png
# Saved cropped line 419 to D://Thesis//Mass_Line_Extraction//output_images_without//line_419.png
# Saved cropped line 420 to D://Thesis//Mass_Line_Extraction//output_images_without//line_420.png
# Saved cropped line 421 to D://Thesis//Mass_Line_Extraction//output_images_without//line_421.png
# Saved cropped line 422 to D://Thesis//Mass_Line_Extraction//output_images_without//line_422.png
# Saved cropped line 423 to D://Thesis//Mass_Line_Extraction//output_images_without//line_423.png
# Saved cropped line 424 to D://Thesis//Mass_Line_Extraction//output_images_without//line_424.png
# Saved cropped line 425 to D://Thesis//Mass_Line_Extraction//output_images_without//line_425.png
# Saved cropped line 426 to D://Thesis//Mass_Line_Extraction//output_images_without//line_426.png
# Saved cropped line 427 to D://Thesis//Mass_Line_Extraction//output_images_without//line_427.png
# Saved cropped line 428 to D://Thesis//Mass_Line_Extraction//output_images_without//line_428.png
# Saved cropped line 429 to D://Thesis//Mass_Line_Extraction//output_images_without//line_429.png
# Saved cropped line 430 to D://Thesis//Mass_Line_Extraction//output_images_without//line_430.png
# Saved cropped line 431 to D://Thesis//Mass_Line_Extraction//output_images_without//line_431.png
# Saved cropped line 432 to D://Thesis//Mass_Line_Extraction//output_images_without//line_432.png
# Saved cropped line 433 to D://Thesis//Mass_Line_Extraction//output_images_without//line_433.png
# Saved cropped line 434 to D://Thesis//Mass_Line_Extraction//output_images_without//line_434.png
# Saved cropped line 435 to D://Thesis//Mass_Line_Extraction//output_images_without//line_435.png
# Saved cropped line 436 to D://Thesis//Mass_Line_Extraction//output_images_without//line_436.png
# Saved cropped line 437 to D://Thesis//Mass_Line_Extraction//output_images_without//line_437.png
# Saved cropped line 438 to D://Thesis//Mass_Line_Extraction//output_images_without//line_438.png
# Saved cropped line 439 to D://Thesis//Mass_Line_Extraction//output_images_without//line_439.png
# Saved cropped line 440 to D://Thesis//Mass_Line_Extraction//output_images_without//line_440.png
# Saved cropped line 441 to D://Thesis//Mass_Line_Extraction//output_images_without//line_441.png
# Saved cropped line 442 to D://Thesis//Mass_Line_Extraction//output_images_without//line_442.png
# Saved cropped line 443 to D://Thesis//Mass_Line_Extraction//output_images_without//line_443.png
# Saved cropped line 444 to D://Thesis//Mass_Line_Extraction//output_images_without//line_444.png
# Saved cropped line 445 to D://Thesis//Mass_Line_Extraction//output_images_without//line_445.png
# Saved cropped line 446 to D://Thesis//Mass_Line_Extraction//output_images_without//line_446.png
# Saved cropped line 447 to D://Thesis//Mass_Line_Extraction//output_images_without//line_447.png
# Saved cropped line 448 to D://Thesis//Mass_Line_Extraction//output_images_without//line_448.png
# Saved cropped line 449 to D://Thesis//Mass_Line_Extraction//output_images_without//line_449.png
# Saved cropped line 450 to D://Thesis//Mass_Line_Extraction//output_images_without//line_450.png
# Saved cropped line 451 to D://Thesis//Mass_Line_Extraction//output_images_without//line_451.png
# Saved cropped line 452 to D://Thesis//Mass_Line_Extraction//output_images_without//line_452.png
# Saved cropped line 453 to D://Thesis//Mass_Line_Extraction//output_images_without//line_453.png
# Saved cropped line 454 to D://Thesis//Mass_Line_Extraction//output_images_without//line_454.png
# Saved cropped line 455 to D://Thesis//Mass_Line_Extraction//output_images_without//line_455.png
# Saved cropped line 456 to D://Thesis//Mass_Line_Extraction//output_images_without//line_456.png
# Saved cropped line 457 to D://Thesis//Mass_Line_Extraction//output_images_without//line_457.png
# Saved cropped line 458 to D://Thesis//Mass_Line_Extraction//output_images_without//line_458.png
# Saved cropped line 459 to D://Thesis//Mass_Line_Extraction//output_images_without//line_459.png
# Saved cropped line 460 to D://Thesis//Mass_Line_Extraction//output_images_without//line_460.png
# Saved cropped line 461 to D://Thesis//Mass_Line_Extraction//output_images_without//line_461.png
# Saved cropped line 462 to D://Thesis//Mass_Line_Extraction//output_images_without//line_462.png
# Saved cropped line 463 to D://Thesis//Mass_Line_Extraction//output_images_without//line_463.png
# Saved cropped line 464 to D://Thesis//Mass_Line_Extraction//output_images_without//line_464.png
# Saved cropped line 465 to D://Thesis//Mass_Line_Extraction//output_images_without//line_465.png
# Saved cropped line 466 to D://Thesis//Mass_Line_Extraction//output_images_without//line_466.png
# Saved cropped line 467 to D://Thesis//Mass_Line_Extraction//output_images_without//line_467.png
# Saved cropped line 468 to D://Thesis//Mass_Line_Extraction//output_images_without//line_468.png
# Saved cropped line 469 to D://Thesis//Mass_Line_Extraction//output_images_without//line_469.png
# Saved cropped line 470 to D://Thesis//Mass_Line_Extraction//output_images_without//line_470.png
# Saved cropped line 471 to D://Thesis//Mass_Line_Extraction//output_images_without//line_471.png
# Saved cropped line 472 to D://Thesis//Mass_Line_Extraction//output_images_without//line_472.png
# Saved cropped line 473 to D://Thesis//Mass_Line_Extraction//output_images_without//line_473.png
# Saved cropped line 474 to D://Thesis//Mass_Line_Extraction//output_images_without//line_474.png
# Saved cropped line 475 to D://Thesis//Mass_Line_Extraction//output_images_without//line_475.png
# Saved cropped line 476 to D://Thesis//Mass_Line_Extraction//output_images_without//line_476.png
# Saved cropped line 477 to D://Thesis//Mass_Line_Extraction//output_images_without//line_477.png
# Saved cropped line 478 to D://Thesis//Mass_Line_Extraction//output_images_without//line_478.png
# Saved cropped line 479 to D://Thesis//Mass_Line_Extraction//output_images_without//line_479.png
# Saved cropped line 480 to D://Thesis//Mass_Line_Extraction//output_images_without//line_480.png
# Saved cropped line 481 to D://Thesis//Mass_Line_Extraction//output_images_without//line_481.png
# Saved cropped line 482 to D://Thesis//Mass_Line_Extraction//output_images_without//line_482.png
# Saved cropped line 483 to D://Thesis//Mass_Line_Extraction//output_images_without//line_483.png
# Saved cropped line 484 to D://Thesis//Mass_Line_Extraction//output_images_without//line_484.png
# Saved cropped line 485 to D://Thesis//Mass_Line_Extraction//output_images_without//line_485.png
# Saved cropped line 486 to D://Thesis//Mass_Line_Extraction//output_images_without//line_486.png
# Saved cropped line 487 to D://Thesis//Mass_Line_Extraction//output_images_without//line_487.png
# Saved cropped line 488 to D://Thesis//Mass_Line_Extraction//output_images_without//line_488.png
# Saved cropped line 489 to D://Thesis//Mass_Line_Extraction//output_images_without//line_489.png
# Saved cropped line 490 to D://Thesis//Mass_Line_Extraction//output_images_without//line_490.png
# Saved cropped line 491 to D://Thesis//Mass_Line_Extraction//output_images_without//line_491.png
# Saved cropped line 492 to D://Thesis//Mass_Line_Extraction//output_images_without//line_492.png
# Saved cropped line 493 to D://Thesis//Mass_Line_Extraction//output_images_without//line_493.png
# Saved cropped line 494 to D://Thesis//Mass_Line_Extraction//output_images_without//line_494.png
# Saved cropped line 495 to D://Thesis//Mass_Line_Extraction//output_images_without//line_495.png
# Saved cropped line 496 to D://Thesis//Mass_Line_Extraction//output_images_without//line_496.png
# Saved cropped line 497 to D://Thesis//Mass_Line_Extraction//output_images_without//line_497.png
# Saved cropped line 498 to D://Thesis//Mass_Line_Extraction//output_images_without//line_498.png
# Saved cropped line 499 to D://Thesis//Mass_Line_Extraction//output_images_without//line_499.png
# Saved cropped line 500 to D://Thesis//Mass_Line_Extraction//output_images_without//line_500.png
# Saved cropped line 501 to D://Thesis//Mass_Line_Extraction//output_images_without//line_501.png
# ...
# Saved cropped line 570 to D://Thesis//Mass_Line_Extraction//output_images_without//line_570.png
# Saved cropped line 571 to D://Thesis//Mass_Line_Extraction//output_images_without//line_571.png
# Saved cropped line 572 to D://Thesis//Mass_Line_Extraction//output_images_without//line_572.png
# Saved cropped line 573 to D://Thesis//Mass_Line_Extraction//output_images_without//line_573.png
# Saved cropped line 574 to D://Thesis//Mass_Line_Extraction//output_images_without//line_574.png
# Saved cropped line 575 to D://Thesis//Mass_Line_Extraction//output_images_without//line_575.png
# Saved cropped line 576 to D://Thesis//Mass_Line_Extraction//output_images_without//line_576.png
# Saved cropped line 577 to D://Thesis//Mass_Line_Extraction//output_images_without//line_577.png
# Saved cropped line 578 to D://Thesis//Mass_Line_Extraction//output_images_without//line_578.png
# Saved cropped line 579 to D://Thesis//Mass_Line_Extraction//output_images_without//line_579.png
# Saved cropped line 580 to D://Thesis//Mass_Line_Extraction//output_images_without//line_580.png
# Saved cropped line 581 to D://Thesis//Mass_Line_Extraction//output_images_without//line_581.png
# Saved cropped line 582 to D://Thesis//Mass_Line_Extraction//output_images_without//line_582.png
# Saved cropped line 583 to D://Thesis//Mass_Line_Extraction//output_images_without//line_583.png
# Saved cropped line 584 to D://Thesis//Mass_Line_Extraction//output_images_without//line_584.png
# Saved cropped line 585 to D://Thesis//Mass_Line_Extraction//output_images_without//line_585.png
# Saved cropped line 586 to D://Thesis//Mass_Line_Extraction//output_images_without//line_586.png
# Saved cropped line 587 to D://Thesis//Mass_Line_Extraction//output_images_without//line_587.png
# Saved cropped line 588 to D://Thesis//Mass_Line_Extraction//output_images_without//line_588.png
# Saved cropped line 589 to D://Thesis//Mass_Line_Extraction//output_images_without//line_589.png
# Saved cropped line 590 to D://Thesis//Mass_Line_Extraction//output_images_without//line_590.png
# Saved cropped line 591 to D://Thesis//Mass_Line_Extraction//output_images_without//line_591.png
# Saved cropped line 592 to D://Thesis//Mass_Line_Extraction//output_images_without//line_592.png
# Saved cropped line 593 to D://Thesis//Mass_Line_Extraction//output_images_without//line_593.png
# Saved cropped line 594 to D://Thesis//Mass_Line_Extraction//output_images_without//line_594.png
# Saved cropped line 595 to D://Thesis//Mass_Line_Extraction//output_images_without//line_595.png
# Saved cropped line 596 to D://Thesis//Mass_Line_Extraction//output_images_without//line_596.png
# Saved cropped line 597 to D://Thesis//Mass_Line_Extraction//output_images_without//line_597.png
# Saved cropped line 598 to D://Thesis//Mass_Line_Extraction//output_images_without//line_598.png
# Saved cropped line 599 to D://Thesis//Mass_Line_Extraction//output_images_without//line_599.png
# Saved cropped line 600 to D://Thesis//Mass_Line_Extraction//output_images_without//line_600.png
# Saved cropped line 601 to D://Thesis//Mass_Line_Extraction//output_images_without//line_601.png
# Saved cropped line 602 to D://Thesis//Mass_Line_Extraction//output_images_without//line_602.png
# Saved cropped line 603 to D://Thesis//Mass_Line_Extraction//output_images_without//line_603.png
# Saved cropped line 604 to D://Thesis//Mass_Line_Extraction//output_images_without//line_604.png
# Saved cropped line 605 to D://Thesis//Mass_Line_Extraction//output_images_without//line_605.png
# Saved cropped line 606 to D://Thesis//Mass_Line_Extraction//output_images_without//line_606.png
# Saved cropped line 607 to D://Thesis//Mass_Line_Extraction//output_images_without//line_607.png
# Saved cropped line 608 to D://Thesis//Mass_Line_Extraction//output_images_without//line_608.png
# Saved cropped line 609 to D://Thesis//Mass_Line_Extraction//output_images_without//line_609.png
# Saved cropped line 610 to D://Thesis//Mass_Line_Extraction//output_images_without//line_610.png
# Saved cropped line 611 to D://Thesis//Mass_Line_Extraction//output_images_without//line_611.png
# Saved cropped line 612 to D://Thesis//Mass_Line_Extraction//output_images_without//line_612.png
# Saved cropped line 613 to D://Thesis//Mass_Line_Extraction//output_images_without//line_613.png
# Saved cropped line 614 to D://Thesis//Mass_Line_Extraction//output_images_without//line_614.png
# Saved cropped line 615 to D://Thesis//Mass_Line_Extraction//output_images_without//line_615.png
# Saved cropped line 616 to D://Thesis//Mass_Line_Extraction//output_images_without//line_616.png
# Saved cropped line 617 to D://Thesis//Mass_Line_Extraction//output_images_without//line_617.png
# Saved cropped line 618 to D://Thesis//Mass_Line_Extraction//output_images_without//line_618.png
# Saved cropped line 619 to D://Thesis//Mass_Line_Extraction//output_images_without//line_619.png
# Saved cropped line 620 to D://Thesis//Mass_Line_Extraction//output_images_without//line_620.png
# Saved cropped line 621 to D://Thesis//Mass_Line_Extraction//output_images_without//line_621.png
# Saved cropped line 622 to D://Thesis//Mass_Line_Extraction//output_images_without//line_622.png
# Saved cropped line 623 to D://Thesis//Mass_Line_Extraction//output_images_without//line_623.png
# Saved cropped line 624 to D://Thesis//Mass_Line_Extraction//output_images_without//line_624.png
# Saved cropped line 625 to D://Thesis//Mass_Line_Extraction//output_images_without//line_625.png
# Saved cropped line 626 to D://Thesis//Mass_Line_Extraction//output_images_without//line_626.png
# Saved cropped line 627 to D://Thesis//Mass_Line_Extraction//output_images_without//line_627.png
# Saved cropped line 628 to D://Thesis//Mass_Line_Extraction//output_images_without//line_628.png
# Saved cropped line 629 to D://Thesis//Mass_Line_Extraction//output_images_without//line_629.png
# Saved cropped line 630 to D://Thesis//Mass_Line_Extraction//output_images_without//line_630.png
# Saved cropped line 631 to D://Thesis//Mass_Line_Extraction//output_images_without//line_631.png
# Saved cropped line 632 to D://Thesis//Mass_Line_Extraction//output_images_without//line_632.png
# Saved cropped line 633 to D://Thesis//Mass_Line_Extraction//output_images_without//line_633.png
# Saved cropped line 634 to D://Thesis//Mass_Line_Extraction//output_images_without//line_634.png
# Saved cropped line 635 to D://Thesis//Mass_Line_Extraction//output_images_without//line_635.png
# Saved cropped line 636 to D://Thesis//Mass_Line_Extraction//output_images_without//line_636.png
# Saved cropped line 637 to D://Thesis//Mass_Line_Extraction//output_images_without//line_637.png
# Saved cropped line 638 to D://Thesis//Mass_Line_Extraction//output_images_without//line_638.png
# Saved cropped line 639 to D://Thesis//Mass_Line_Extraction//output_images_without//line_639.png
# Saved cropped line 640 to D://Thesis//Mass_Line_Extraction//output_images_without//line_640.png
# Saved cropped line 641 to D://Thesis//Mass_Line_Extraction//output_images_without//line_641.png
# Saved cropped line 642 to D://Thesis//Mass_Line_Extraction//output_images_without//line_642.png
# Saved cropped line 643 to D://Thesis//Mass_Line_Extraction//output_images_without//line_643.png
# Saved cropped line 644 to D://Thesis//Mass_Line_Extraction//output_images_without//line_644.png
# Saved cropped line 645 to D://Thesis//Mass_Line_Extraction//output_images_without//line_645.png
# Saved cropped line 646 to D://Thesis//Mass_Line_Extraction//output_images_without//line_646.png
# Saved cropped line 647 to D://Thesis//Mass_Line_Extraction//output_images_without//line_647.png
# Saved cropped line 648 to D://Thesis//Mass_Line_Extraction//output_images_without//line_648.png
# Saved cropped line 649 to D://Thesis//Mass_Line_Extraction//output_images_without//line_649.png
# Saved cropped line 650 to D://Thesis//Mass_Line_Extraction//output_images_without//line_650.png
# Saved cropped line 651 to D://Thesis//Mass_Line_Extraction//output_images_without//line_651.png
# Saved cropped line 652 to D://Thesis//Mass_Line_Extraction//output_images_without//line_652.png
# Saved cropped line 653 to D://Thesis//Mass_Line_Extraction//output_images_without//line_653.png
# Saved cropped line 654 to D://Thesis//Mass_Line_Extraction//output_images_without//line_654.png
# Saved cropped line 655 to D://Thesis//Mass_Line_Extraction//output_images_without//line_655.png
# Saved cropped line 656 to D://Thesis//Mass_Line_Extraction//output_images_without//line_656.png
# Saved cropped line 657 to D://Thesis//Mass_Line_Extraction//output_images_without//line_657.png
# Saved cropped line 658 to D://Thesis//Mass_Line_Extraction//output_images_without//line_658.png
# Saved cropped line 659 to D://Thesis//Mass_Line_Extraction//output_images_without//line_659.png
# Saved cropped line 660 to D://Thesis//Mass_Line_Extraction//output_images_without//line_660.png
# Saved cropped line 661 to D://Thesis//Mass_Line_Extraction//output_images_without//line_661.png
# Saved cropped line 662 to D://Thesis//Mass_Line_Extraction//output_images_without//line_662.png
# Saved cropped line 663 to D://Thesis//Mass_Line_Extraction//output_images_without//line_663.png
# Saved cropped line 664 to D://Thesis//Mass_Line_Extraction//output_images_without//line_664.png
# Saved cropped line 665 to D://Thesis//Mass_Line_Extraction//output_images_without//line_665.png
# Saved cropped line 666 to D://Thesis//Mass_Line_Extraction//output_images_without//line_666.png
# Saved cropped line 667 to D://Thesis//Mass_Line_Extraction//output_images_without//line_667.png
# Saved cropped line 668 to D://Thesis//Mass_Line_Extraction//output_images_without//line_668.png
# Saved cropped line 669 to D://Thesis//Mass_Line_Extraction//output_images_without//line_669.png
# Saved cropped line 670 to D://Thesis//Mass_Line_Extraction//output_images_without//line_670.png
# Saved cropped line 671 to D://Thesis//Mass_Line_Extraction//output_images_without//line_671.png
# Saved cropped line 672 to D://Thesis//Mass_Line_Extraction//output_images_without//line_672.png
# Saved cropped line 673 to D://Thesis//Mass_Line_Extraction//output_images_without//line_673.png
# Saved cropped line 674 to D://Thesis//Mass_Line_Extraction//output_images_without//line_674.png
# Saved cropped line 675 to D://Thesis//Mass_Line_Extraction//output_images_without//line_675.png
# Saved cropped line 676 to D://Thesis//Mass_Line_Extraction//output_images_without//line_676.png
# Saved cropped line 677 to D://Thesis//Mass_Line_Extraction//output_images_without//line_677.png
# Saved cropped line 678 to D://Thesis//Mass_Line_Extraction//output_images_without//line_678.png
# Saved cropped line 679 to D://Thesis//Mass_Line_Extraction//output_images_without//line_679.png
# Saved cropped line 680 to D://Thesis//Mass_Line_Extraction//output_images_without//line_680.png
# Saved cropped line 681 to D://Thesis//Mass_Line_Extraction//output_images_without//line_681.png
# Saved cropped line 682 to D://Thesis//Mass_Line_Extraction//output_images_without//line_682.png
# Saved cropped line 683 to D://Thesis//Mass_Line_Extraction//output_images_without//line_683.png
# Saved cropped line 684 to D://Thesis//Mass_Line_Extraction//output_images_without//line_684.png
# Saved cropped line 685 to D://Thesis//Mass_Line_Extraction//output_images_without//line_685.png
# Saved cropped line 686 to D://Thesis//Mass_Line_Extraction//output_images_without//line_686.png
# Saved cropped line 687 to D://Thesis//Mass_Line_Extraction//output_images_without//line_687.png
# Saved cropped line 688 to D://Thesis//Mass_Line_Extraction//output_images_without//line_688.png
# Saved cropped line 689 to D://Thesis//Mass_Line_Extraction//output_images_without//line_689.png
# Saved cropped line 690 to D://Thesis//Mass_Line_Extraction//output_images_without//line_690.png
# Saved cropped line 691 to D://Thesis//Mass_Line_Extraction//output_images_without//line_691.png
# Saved cropped line 692 to D://Thesis//Mass_Line_Extraction//output_images_without//line_692.png
# Saved cropped line 693 to D://Thesis//Mass_Line_Extraction//output_images_without//line_693.png
# Saved cropped line 694 to D://Thesis//Mass_Line_Extraction//output_images_without//line_694.png
# Saved cropped line 695 to D://Thesis//Mass_Line_Extraction//output_images_without//line_695.png
# Saved cropped line 696 to D://Thesis//Mass_Line_Extraction//output_images_without//line_696.png
# Saved cropped line 697 to D://Thesis//Mass_Line_Extraction//output_images_without//line_697.png
# Saved cropped line 698 to D://Thesis//Mass_Line_Extraction//output_images_without//line_698.png
# Saved cropped line 699 to D://Thesis//Mass_Line_Extraction//output_images_without//line_699.png
# Saved cropped line 700 to D://Thesis//Mass_Line_Extraction//output_images_without//line_700.png
# Saved cropped line 701 to D://Thesis//Mass_Line_Extraction//output_images_without//line_701.png
# Saved cropped line 702 to D://Thesis//Mass_Line_Extraction//output_images_without//line_702.png
# Saved cropped line 703 to D://Thesis//Mass_Line_Extraction//output_images_without//line_703.png
# Saved cropped line 704 to D://Thesis//Mass_Line_Extraction//output_images_without//line_704.png
# Saved cropped line 705 to D://Thesis//Mass_Line_Extraction//output_images_without//line_705.png
# Saved cropped line 706 to D://Thesis//Mass_Line_Extraction//output_images_without//line_706.png
# Saved cropped line 707 to D://Thesis//Mass_Line_Extraction//output_images_without//line_707.png
# Saved cropped line 708 to D://Thesis//Mass_Line_Extraction//output_images_without//line_708.png
# Saved cropped line 709 to D://Thesis//Mass_Line_Extraction//output_images_without//line_709.png
# Saved cropped line 710 to D://Thesis//Mass_Line_Extraction//output_images_without//line_710.png
# Saved cropped line 711 to D://Thesis//Mass_Line_Extraction//output_images_without//line_711.png
# Saved cropped line 712 to D://Thesis//Mass_Line_Extraction//output_images_without//line_712.png
# Saved cropped line 713 to D://Thesis//Mass_Line_Extraction//output_images_without//line_713.png
# Saved cropped line 714 to D://Thesis//Mass_Line_Extraction//output_images_without//line_714.png
# Saved cropped line 715 to D://Thesis//Mass_Line_Extraction//output_images_without//line_715.png
# Saved cropped line 716 to D://Thesis//Mass_Line_Extraction//output_images_without//line_716.png
# Saved cropped line 717 to D://Thesis//Mass_Line_Extraction//output_images_without//line_717.png
# Saved cropped line 718 to D://Thesis//Mass_Line_Extraction//output_images_without//line_718.png
# Saved cropped line 719 to D://Thesis//Mass_Line_Extraction//output_images_without//line_719.png
# Saved cropped line 720 to D://Thesis//Mass_Line_Extraction//output_images_without//line_720.png
# Saved cropped line 721 to D://Thesis//Mass_Line_Extraction//output_images_without//line_721.png
# Saved cropped line 722 to D://Thesis//Mass_Line_Extraction//output_images_without//line_722.png
# Saved cropped line 723 to D://Thesis//Mass_Line_Extraction//output_images_without//line_723.png
# Saved cropped line 724 to D://Thesis//Mass_Line_Extraction//output_images_without//line_724.png
# Saved cropped line 725 to D://Thesis//Mass_Line_Extraction//output_images_without//line_725.png
# Saved cropped line 726 to D://Thesis//Mass_Line_Extraction//output_images_without//line_726.png
# Saved cropped line 727 to D://Thesis//Mass_Line_Extraction//output_images_without//line_727.png
# Saved cropped line 728 to D://Thesis//Mass_Line_Extraction//output_images_without//line_728.png
# Saved cropped line 729 to D://Thesis//Mass_Line_Extraction//output_images_without//line_729.png
# Saved cropped line 730 to D://Thesis//Mass_Line_Extraction//output_images_without//line_730.png
# Saved cropped line 731 to D://Thesis//Mass_Line_Extraction//output_images_without//line_731.png
# Saved cropped line 732 to D://Thesis//Mass_Line_Extraction//output_images_without//line_732.png
# Saved cropped line 733 to D://Thesis//Mass_Line_Extraction//output_images_without//line_733.png
# Saved cropped line 734 to D://Thesis//Mass_Line_Extraction//output_images_without//line_734.png
# Saved cropped line 735 to D://Thesis//Mass_Line_Extraction//output_images_without//line_735.png

# %% [markdown]
# extracting dataset from IAM dataset

# %%
import os

#For printed
# image_path = 'D://Thesis//Mass_Line_Extraction//output_images//printed'
# output_dir_without = 'D://Thesis//Mass_Line_Extraction//output_images_data//Printed'

#For Handwriting
image_path = 'D://Thesis//Mass_Line_Extraction//output_images//handwritten'
output_dir_without = 'D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten'

# List all files in the directory
files = os.listdir(image_path)
cnt = 10000
# Loop through the files and print the full path
for file in files:
    full_path = os.path.join(image_path, file)
    # cv2.imread(full_path)
    cnt = testing_calculate_projection_profile_and_crop_lines(full_path, output_dir_without, cnt)
# Out:
# Saved cropped line 10000 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10000.png
# Saved cropped line 10001 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10001.png
# Saved cropped line 10002 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10002.png
# Saved cropped line 10003 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10003.png
# Saved cropped line 10004 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10004.png
# Saved cropped line 10005 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10005.png
# Saved cropped line 10006 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10006.png
# Saved cropped line 10007 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10007.png
# Saved cropped line 10008 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10008.png
# Saved cropped line 10009 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10009.png
# Saved cropped line 10010 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10010.png
# Saved cropped line 10011 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10011.png
# Saved cropped line 10012 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10012.png
# Saved cropped line 10013 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10013.png
# Saved cropped line 10014 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10014.png
# Saved cropped line 10015 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10015.png
# Saved cropped line 10016 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10016.png
# Saved cropped line 10017 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10017.png
# Saved cropped line 10018 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10018.png
# Saved cropped line 10019 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10019.png
# Saved cropped line 10020 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10020.png
# Saved cropped line 10021 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10021.png
# Saved cropped line 10022 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10022.png
# Saved cropped line 10023 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10023.png
# Saved cropped line 10024 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10024.png
# Saved cropped line 10025 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10025.png
# Saved cropped line 10026 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10026.png
# Saved cropped line 10027 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10027.png
# Saved cropped line 10028 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10028.png
# Saved cropped line 10029 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10029.png
# Saved cropped line 10030 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10030.png
# Saved cropped line 10031 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10031.png
# Saved cropped line 10032 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10032.png
# Saved cropped line 10033 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10033.png
# Saved cropped line 10034 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10034.png
# Saved cropped line 10035 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10035.png
# Saved cropped line 10036 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10036.png
# Saved cropped line 10037 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10037.png
# Saved cropped line 10038 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10038.png
# Saved cropped line 10039 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10039.png
# Saved cropped line 10040 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10040.png
# Saved cropped line 10041 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10041.png
# Saved cropped line 10042 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10042.png
# Saved cropped line 10043 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10043.png
# Saved cropped line 10044 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10044.png
# Saved cropped line 10045 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10045.png
# Saved cropped line 10046 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10046.png
# Saved cropped line 10047 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10047.png
# Saved cropped line 10048 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10048.png
# Saved cropped line 10049 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10049.png
# Saved cropped line 10050 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10050.png
# Saved cropped line 10051 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10051.png
# Saved cropped line 10052 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10052.png
# Saved cropped line 10053 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10053.png
# Saved cropped line 10054 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10054.png
# Saved cropped line 10055 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10055.png
# Saved cropped line 10056 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10056.png
# Saved cropped line 10057 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10057.png
# Saved cropped line 10058 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10058.png
# Saved cropped line 10059 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10059.png
# Saved cropped line 10060 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10060.png
# Saved cropped line 10061 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10061.png
# Saved cropped line 10062 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10062.png
# Saved cropped line 10063 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10063.png
# Saved cropped line 10064 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10064.png
# Saved cropped line 10065 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10065.png
# Saved cropped line 10066 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10066.png
# Saved cropped line 10067 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10067.png
# Saved cropped line 10068 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10068.png
# Saved cropped line 10069 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10069.png
# Saved cropped line 10070 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10070.png
# Saved cropped line 10071 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10071.png
# Saved cropped line 10072 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10072.png
# Saved cropped line 10073 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10073.png
# Saved cropped line 10074 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10074.png
# Saved cropped line 10075 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10075.png
# Saved cropped line 10076 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10076.png
# Saved cropped line 10077 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10077.png
# Saved cropped line 10078 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10078.png
# Saved cropped line 10079 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10079.png
# Saved cropped line 10080 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10080.png
# Saved cropped line 10081 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10081.png
# Saved cropped line 10082 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10082.png
# Saved cropped line 10083 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10083.png
# Saved cropped line 10084 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10084.png
# Saved cropped line 10085 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10085.png
# Saved cropped line 10086 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10086.png
# Saved cropped line 10087 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10087.png
# Saved cropped line 10088 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10088.png
# Saved cropped line 10089 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10089.png
# Saved cropped line 10090 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10090.png
# Saved cropped line 10091 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10091.png
# Saved cropped line 10092 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10092.png
# Saved cropped line 10093 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10093.png
# Saved cropped line 10094 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10094.png
# Saved cropped line 10095 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10095.png
# Saved cropped line 10096 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10096.png
# Saved cropped line 10097 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10097.png
# Saved cropped line 10098 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10098.png
# Saved cropped line 10099 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10099.png
# Saved cropped line 10100 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10100.png
# Saved cropped line 10101 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10101.png
# Saved cropped line 10102 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10102.png
# Saved cropped line 10103 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10103.png
# Saved cropped line 10104 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10104.png
# Saved cropped line 10105 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10105.png
# Saved cropped line 10106 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10106.png
# Saved cropped line 10107 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10107.png
# Saved cropped line 10108 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10108.png
# Saved cropped line 10109 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10109.png
# Saved cropped line 10110 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10110.png
# Saved cropped line 10111 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10111.png
# Saved cropped line 10112 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10112.png
# Saved cropped line 10113 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10113.png
# Saved cropped line 10114 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10114.png
# Saved cropped line 10115 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10115.png
# Saved cropped line 10116 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10116.png
# Saved cropped line 10117 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10117.png
# Saved cropped line 10118 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10118.png
# Saved cropped line 10119 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10119.png
# Saved cropped line 10120 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10120.png
# Saved cropped line 10121 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10121.png
# Saved cropped line 10122 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10122.png
# Saved cropped line 10123 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10123.png
# Saved cropped line 10124 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10124.png
# Saved cropped line 10125 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10125.png
# Saved cropped line 10126 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10126.png
# Saved cropped line 10127 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10127.png
# Saved cropped line 10128 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10128.png
# Saved cropped line 10129 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10129.png
# Saved cropped line 10130 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10130.png
# Saved cropped line 10131 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10131.png
# Saved cropped line 10132 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10132.png
# Saved cropped line 10133 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10133.png
# Saved cropped line 10134 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10134.png
# Saved cropped line 10135 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10135.png
# Saved cropped line 10136 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10136.png
# Saved cropped line 10137 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10137.png
# Saved cropped line 10138 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10138.png
# Saved cropped line 10139 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10139.png
# Saved cropped line 10140 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10140.png
# Saved cropped line 10141 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10141.png
# Saved cropped line 10142 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10142.png
# Saved cropped line 10143 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10143.png
# Saved cropped line 10144 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10144.png
# Saved cropped line 10145 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10145.png
# Saved cropped line 10146 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10146.png
# Saved cropped line 10147 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10147.png
# Saved cropped line 10148 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10148.png
# Saved cropped line 10149 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10149.png
# Saved cropped line 10150 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10150.png
# Saved cropped line 10151 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10151.png
# Saved cropped line 10152 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10152.png
# Saved cropped line 10153 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10153.png
# Saved cropped line 10154 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10154.png
# Saved cropped line 10155 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10155.png
# Saved cropped line 10156 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10156.png
# Saved cropped line 10157 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10157.png
# Saved cropped line 10158 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10158.png
# Saved cropped line 10159 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10159.png
# Saved cropped line 10160 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10160.png
# Saved cropped line 10161 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10161.png
# Saved cropped line 10162 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10162.png
# Saved cropped line 10163 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10163.png
# Saved cropped line 10164 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10164.png
# Saved cropped line 10165 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10165.png
# Saved cropped line 10166 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10166.png
# Saved cropped line 10167 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10167.png
# Saved cropped line 10168 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10168.png
# Saved cropped line 10169 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10169.png
# Saved cropped line 10170 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10170.png
# Saved cropped line 10171 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10171.png
# Saved cropped line 10172 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10172.png
# Saved cropped line 10173 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10173.png
# Saved cropped line 10174 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10174.png
# Saved cropped line 10175 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10175.png
# Saved cropped line 10176 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10176.png
# Saved cropped line 10177 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10177.png
# Saved cropped line 10178 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10178.png
# Saved cropped line 10179 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10179.png
# Saved cropped line 10180 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10180.png
# Saved cropped line 10181 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10181.png
# Saved cropped line 10182 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10182.png
# Saved cropped line 10183 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10183.png
# Saved cropped line 10184 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10184.png
# Saved cropped line 10185 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10185.png
# Saved cropped line 10186 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10186.png
# Saved cropped line 10187 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10187.png
# Saved cropped line 10188 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10188.png
# Saved cropped line 10189 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10189.png
# Saved cropped line 10190 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10190.png
# Saved cropped line 10191 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10191.png
# Saved cropped line 10192 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10192.png
# Saved cropped line 10193 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10193.png
# Saved cropped line 10194 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10194.png
# Saved cropped line 10195 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10195.png
# Saved cropped line 10196 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10196.png
# Saved cropped line 10197 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10197.png
# Saved cropped line 10198 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10198.png
# Saved cropped line 10199 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10199.png
# Saved cropped line 10200 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10200.png
# Saved cropped line 10201 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10201.png
# Saved cropped line 10202 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10202.png
# Saved cropped line 10203 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10203.png
# Saved cropped line 10204 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10204.png
# Saved cropped line 10205 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10205.png
# Saved cropped line 10206 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10206.png
# Saved cropped line 10207 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10207.png
# Saved cropped line 10208 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10208.png
# Saved cropped line 10209 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10209.png
# Saved cropped line 10210 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10210.png
# Saved cropped line 10211 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10211.png
# Saved cropped line 10212 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10212.png
# Saved cropped line 10213 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10213.png
# Saved cropped line 10214 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10214.png
# Saved cropped line 10215 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10215.png
# Saved cropped line 10216 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10216.png
# Saved cropped line 10217 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10217.png
# Saved cropped line 10218 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10218.png
# Saved cropped line 10219 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10219.png
# Saved cropped line 10220 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10220.png
# Saved cropped line 10221 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10221.png
# Saved cropped line 10222 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10222.png
# Saved cropped line 10223 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10223.png
# Saved cropped line 10224 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10224.png
# Saved cropped line 10225 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10225.png
# Saved cropped line 10226 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10226.png
# Saved cropped line 10227 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10227.png
# Saved cropped line 10228 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10228.png
# Saved cropped line 10229 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10229.png
# Saved cropped line 10230 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10230.png
# Saved cropped line 10231 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10231.png
# Saved cropped line 10232 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10232.png
# Saved cropped line 10233 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10233.png
# Saved cropped line 10234 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10234.png
# Saved cropped line 10235 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10235.png
# Saved cropped line 10236 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10236.png
# Saved cropped line 10237 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10237.png
# Saved cropped line 10238 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10238.png
# Saved cropped line 10239 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10239.png
# Saved cropped line 10240 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10240.png
# Saved cropped line 10241 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10241.png
# Saved cropped line 10242 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10242.png
# Saved cropped line 10243 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10243.png
# Saved cropped line 10244 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10244.png
# Saved cropped line 10245 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10245.png
# Saved cropped line 10246 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10246.png
# Saved cropped line 10247 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10247.png
# Saved cropped line 10248 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10248.png
# Saved cropped line 10249 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10249.png
# Saved cropped line 10250 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10250.png
# Saved cropped line 10251 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10251.png
# Saved cropped line 10252 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10252.png
# Saved cropped line 10253 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10253.png
# Saved cropped line 10254 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10254.png
# Saved cropped line 10255 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10255.png
# Saved cropped line 10256 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10256.png
# Saved cropped line 10257 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10257.png
# Saved cropped line 10258 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10258.png
# Saved cropped line 10259 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10259.png
# Saved cropped line 10260 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10260.png
# Saved cropped line 10261 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10261.png
# Saved cropped line 10262 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10262.png
# Saved cropped line 10263 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10263.png
# Saved cropped line 10264 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10264.png
# Saved cropped line 10265 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10265.png
# Saved cropped line 10266 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10266.png
# Saved cropped line 10267 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10267.png
# Saved cropped line 10268 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10268.png
# Saved cropped line 10269 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10269.png
# Saved cropped line 10270 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10270.png
# Saved cropped line 10271 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10271.png
# Saved cropped line 10272 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10272.png
# Saved cropped line 10273 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10273.png
# Saved cropped line 10274 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10274.png
# Saved cropped line 10275 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10275.png
# Saved cropped line 10276 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10276.png
# Saved cropped line 10277 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10277.png
# Saved cropped line 10278 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10278.png
# Saved cropped line 10279 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10279.png
# Saved cropped line 10280 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10280.png
# Saved cropped line 10281 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10281.png
# Saved cropped line 10282 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10282.png
# Saved cropped line 10283 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10283.png
# Saved cropped line 10284 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10284.png
# Saved cropped line 10285 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10285.png
# Saved cropped line 10286 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10286.png
# Saved cropped line 10287 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10287.png
# Saved cropped line 10288 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10288.png
# Saved cropped line 10289 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10289.png
# Saved cropped line 10290 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10290.png
# Saved cropped line 10291 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10291.png
# Saved cropped line 10292 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10292.png
# Saved cropped line 10293 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10293.png
# Saved cropped line 10294 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10294.png
# Saved cropped line 10295 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10295.png
# Saved cropped line 10296 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10296.png
# Saved cropped line 10297 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10297.png
# Saved cropped line 10298 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10298.png
# Saved cropped line 10299 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10299.png
# Saved cropped line 10300 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10300.png
# Saved cropped line 10301 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10301.png
# Saved cropped line 10302 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10302.png
# Saved cropped line 10303 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10303.png
# Saved cropped line 10304 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10304.png
# Saved cropped line 10305 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10305.png
# Saved cropped line 10306 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10306.png
# Saved cropped line 10307 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10307.png
# Saved cropped line 10308 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10308.png
# Saved cropped line 10309 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10309.png
# Saved cropped line 10310 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10310.png
# Saved cropped line 10311 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10311.png
# Saved cropped line 10312 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10312.png
# Saved cropped line 10313 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10313.png
# Saved cropped line 10314 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10314.png
# Saved cropped line 10315 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10315.png
# Saved cropped line 10316 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10316.png
# Saved cropped line 10317 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10317.png
# Saved cropped line 10318 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10318.png
# Saved cropped line 10319 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10319.png
# Saved cropped line 10320 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10320.png
# Saved cropped line 10321 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10321.png
# Saved cropped line 10322 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10322.png
# Saved cropped line 10323 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10323.png
# Saved cropped line 10324 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10324.png
# Saved cropped line 10325 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10325.png
# Saved cropped line 10326 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10326.png
# Saved cropped line 10327 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10327.png
# Saved cropped line 10328 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10328.png
# Saved cropped line 10329 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10329.png
# Saved cropped line 10330 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10330.png
# Saved cropped line 10331 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10331.png
# Saved cropped line 10332 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10332.png
# Saved cropped line 10333 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10333.png
# Saved cropped line 10334 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10334.png
# Saved cropped line 10335 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10335.png
# Saved cropped line 10336 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10336.png
# Saved cropped line 10337 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10337.png
# Saved cropped line 10338 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10338.png
# Saved cropped line 10339 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10339.png
# Saved cropped line 10340 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10340.png
# Saved cropped line 10341 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10341.png
# Saved cropped line 10342 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10342.png
# Saved cropped line 10343 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10343.png
# Saved cropped line 10344 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10344.png
# Saved cropped line 10345 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10345.png
# Saved cropped line 10346 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10346.png
# Saved cropped line 10347 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10347.png
# Saved cropped line 10348 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10348.png
# Saved cropped line 10349 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10349.png
# Saved cropped line 10350 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10350.png
# Saved cropped line 10351 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10351.png
# Saved cropped line 10352 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10352.png
# Saved cropped line 10353 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10353.png
# Saved cropped line 10354 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10354.png
# Saved cropped line 10355 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10355.png
# Saved cropped line 10356 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10356.png
# Saved cropped line 10357 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10357.png
# Saved cropped line 10358 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10358.png
# Saved cropped line 10359 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10359.png
# Saved cropped line 10360 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10360.png
# Saved cropped line 10361 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10361.png
# Saved cropped line 10362 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10362.png
# Saved cropped line 10363 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10363.png
# Saved cropped line 10364 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10364.png
# Saved cropped line 10365 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10365.png
# Saved cropped line 10366 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10366.png
# Saved cropped line 10367 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10367.png
# Saved cropped line 10368 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10368.png
# Saved cropped line 10369 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10369.png
# Saved cropped line 10370 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10370.png
# Saved cropped line 10371 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10371.png
# Saved cropped line 10372 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10372.png
# Saved cropped line 10373 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10373.png
# Saved cropped line 10374 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10374.png
# Saved cropped line 10375 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10375.png
# Saved cropped line 10376 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10376.png
# Saved cropped line 10377 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10377.png
# Saved cropped line 10378 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10378.png
# Saved cropped line 10379 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10379.png
# Saved cropped line 10380 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10380.png
# Saved cropped line 10381 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10381.png
# Saved cropped line 10382 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10382.png
# Saved cropped line 10383 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10383.png
# Saved cropped line 10384 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10384.png
# Saved cropped line 10385 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10385.png
# Saved cropped line 10386 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10386.png
# Saved cropped line 10387 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10387.png
# Saved cropped line 10388 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10388.png
# Saved cropped line 10389 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10389.png
# Saved cropped line 10390 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10390.png
# Saved cropped line 10391 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10391.png
# Saved cropped line 10392 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10392.png
# Saved cropped line 10393 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10393.png
# Saved cropped line 10394 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10394.png
# Saved cropped line 10395 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10395.png
# Saved cropped line 10396 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10396.png
# Saved cropped line 10397 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10397.png
# Saved cropped line 10398 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10398.png
# Saved cropped line 10399 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10399.png
# Saved cropped line 10400 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10400.png
# Saved cropped line 10401 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10401.png
# Saved cropped line 10402 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10402.png
# Saved cropped line 10403 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10403.png
# Saved cropped line 10404 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10404.png
# Saved cropped line 10405 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10405.png
# Saved cropped line 10406 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10406.png
# Saved cropped line 10407 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10407.png
# Saved cropped line 10408 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10408.png
# Saved cropped line 10409 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10409.png
# Saved cropped line 10410 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10410.png
# Saved cropped line 10411 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10411.png
# Saved cropped line 10412 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10412.png
# Saved cropped line 10413 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10413.png
# Saved cropped line 10414 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10414.png
# Saved cropped line 10415 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10415.png
# Saved cropped line 10416 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10416.png
# Saved cropped line 10417 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10417.png
# Saved cropped line 10418 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10418.png
# Saved cropped line 10419 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10419.png
# Saved cropped line 10420 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10420.png
# Saved cropped line 10421 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10421.png
# Saved cropped line 10422 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10422.png
# Saved cropped line 10423 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10423.png
# Saved cropped line 10424 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10424.png
# Saved cropped line 10425 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10425.png
# Saved cropped line 10426 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10426.png
# Saved cropped line 10427 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10427.png
# Saved cropped line 10428 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10428.png
# Saved cropped line 10429 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10429.png
# Saved cropped line 10430 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10430.png
# Saved cropped line 10431 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10431.png
# Saved cropped line 10432 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10432.png
# Saved cropped line 10433 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10433.png
# Saved cropped line 10434 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10434.png
# Saved cropped line 10435 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10435.png
# Saved cropped line 10436 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10436.png
# Saved cropped line 10437 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10437.png
# Saved cropped line 10438 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10438.png
# Saved cropped line 10439 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10439.png
# ...
# Saved cropped line 10568 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10568.png
# Saved cropped line 10569 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10569.png
# Saved cropped line 10570 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10570.png
# Saved cropped line 10571 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10571.png
# Saved cropped line 10572 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10572.png
# Saved cropped line 10573 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10573.png
# Saved cropped line 10574 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10574.png
# Saved cropped line 10575 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10575.png
# Saved cropped line 10576 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10576.png
# Saved cropped line 10577 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10577.png
# Saved cropped line 10578 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10578.png
# Saved cropped line 10579 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10579.png
# Saved cropped line 10580 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10580.png
# Saved cropped line 10581 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10581.png
# Saved cropped line 10582 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10582.png
# Saved cropped line 10583 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10583.png
# Saved cropped line 10584 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10584.png
# Saved cropped line 10585 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10585.png
# Saved cropped line 10586 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10586.png
# Saved cropped line 10587 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10587.png
# Saved cropped line 10588 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10588.png
# Saved cropped line 10589 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10589.png
# Saved cropped line 10590 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10590.png
# Saved cropped line 10591 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10591.png
# Saved cropped line 10592 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10592.png
# Saved cropped line 10593 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10593.png
# Saved cropped line 10594 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10594.png
# Saved cropped line 10595 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10595.png
# Saved cropped line 10596 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10596.png
# Saved cropped line 10597 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10597.png
# Saved cropped line 10598 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10598.png
# Saved cropped line 10599 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10599.png
# Saved cropped line 10600 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10600.png
# Saved cropped line 10601 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10601.png
# Saved cropped line 10602 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10602.png
# Saved cropped line 10603 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10603.png
# Saved cropped line 10604 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10604.png
# Saved cropped line 10605 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10605.png
# Saved cropped line 10606 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10606.png
# Saved cropped line 10607 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10607.png
# Saved cropped line 10608 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10608.png
# Saved cropped line 10609 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10609.png
# Saved cropped line 10610 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10610.png
# Saved cropped line 10611 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10611.png
# Saved cropped line 10612 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10612.png
# Saved cropped line 10613 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10613.png
# Saved cropped line 10614 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10614.png
# Saved cropped line 10615 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10615.png
# Saved cropped line 10616 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10616.png
# Saved cropped line 10617 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10617.png
# Saved cropped line 10618 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10618.png
# Saved cropped line 10619 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10619.png
# Saved cropped line 10620 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10620.png
# Saved cropped line 10621 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10621.png
# Saved cropped line 10622 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10622.png
# Saved cropped line 10623 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10623.png
# Saved cropped line 10624 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10624.png
# Saved cropped line 10625 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10625.png
# Saved cropped line 10626 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10626.png
# Saved cropped line 10627 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10627.png
# Saved cropped line 10628 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10628.png
# Saved cropped line 10629 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10629.png
# Saved cropped line 10630 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10630.png
# Saved cropped line 10631 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10631.png
# Saved cropped line 10632 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10632.png
# Saved cropped line 10633 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10633.png
# Saved cropped line 10634 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10634.png
# Saved cropped line 10635 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10635.png
# Saved cropped line 10636 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10636.png
# Saved cropped line 10637 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10637.png
# Saved cropped line 10638 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10638.png
# Saved cropped line 10639 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10639.png
# Saved cropped line 10640 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10640.png
# Saved cropped line 10641 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10641.png
# Saved cropped line 10642 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10642.png
# Saved cropped line 10643 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10643.png
# Saved cropped line 10644 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10644.png
# Saved cropped line 10645 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10645.png
# Saved cropped line 10646 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10646.png
# Saved cropped line 10647 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10647.png
# Saved cropped line 10648 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10648.png
# Saved cropped line 10649 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10649.png
# Saved cropped line 10650 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10650.png
# Saved cropped line 10651 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10651.png
# Saved cropped line 10652 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10652.png
# Saved cropped line 10653 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10653.png
# Saved cropped line 10654 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10654.png
# Saved cropped line 10655 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10655.png
# Saved cropped line 10656 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10656.png
# Saved cropped line 10657 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10657.png
# Saved cropped line 10658 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10658.png
# Saved cropped line 10659 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10659.png
# Saved cropped line 10660 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10660.png
# Saved cropped line 10661 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10661.png
# Saved cropped line 10662 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10662.png
# Saved cropped line 10663 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10663.png
# Saved cropped line 10664 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10664.png
# Saved cropped line 10665 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10665.png
# Saved cropped line 10666 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10666.png
# Saved cropped line 10667 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10667.png
# Saved cropped line 10668 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10668.png
# Saved cropped line 10669 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10669.png
# Saved cropped line 10670 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10670.png
# Saved cropped line 10671 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10671.png
# Saved cropped line 10672 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10672.png
# Saved cropped line 10673 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10673.png
# Saved cropped line 10674 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10674.png
# Saved cropped line 10675 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10675.png
# Saved cropped line 10676 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10676.png
# Saved cropped line 10677 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10677.png
# Saved cropped line 10678 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10678.png
# Saved cropped line 10679 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10679.png
# Saved cropped line 10680 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10680.png
# Saved cropped line 10681 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10681.png
# Saved cropped line 10682 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10682.png
# Saved cropped line 10683 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10683.png
# Saved cropped line 10684 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10684.png
# Saved cropped line 10685 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10685.png
# Saved cropped line 10686 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10686.png
# Saved cropped line 10687 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10687.png
# Saved cropped line 10688 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10688.png
# Saved cropped line 10689 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10689.png
# Saved cropped line 10690 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10690.png
# Saved cropped line 10691 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10691.png
# Saved cropped line 10692 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10692.png
# Saved cropped line 10693 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10693.png
# Saved cropped line 10694 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10694.png
# Saved cropped line 10695 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10695.png
# Saved cropped line 10696 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10696.png
# Saved cropped line 10697 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10697.png
# Saved cropped line 10698 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10698.png
# Saved cropped line 10699 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10699.png
# Saved cropped line 10700 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10700.png
# Saved cropped line 10701 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10701.png
# Saved cropped line 10702 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10702.png
# Saved cropped line 10703 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10703.png
# Saved cropped line 10704 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10704.png
# Saved cropped line 10705 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10705.png
# Saved cropped line 10706 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10706.png
# Saved cropped line 10707 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10707.png
# Saved cropped line 10708 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10708.png
# Saved cropped line 10709 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10709.png
# Saved cropped line 10710 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10710.png
# Saved cropped line 10711 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10711.png
# Saved cropped line 10712 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10712.png
# Saved cropped line 10713 to D://Thesis//Mass_Line_Extraction//output_images_data//Handwritten\line_10713.png

# %% [markdown]
# # Seperating handwriting and printed portions from IAM dataset

# %%
import cv2


def seperate_image_section_cropping_handwritten_printed_IAM(image_path, handwritten_dir, printed_dir, cnt):
    # Load the image
    image = cv2.imread(image_path)

    # Get image dimensions
    height, width, _ = image.shape
    handwritten_dir = os.path.join(handwritten_dir, f"line_{cnt}.png")
    printed_dir = os.path.join(printed_dir, f"line_{cnt}.png")
    # Crop first half (top half) for printed text
    printed_crop = image[360:620, :]
    cv2.imwrite(handwritten_dir, printed_crop)

    # Crop second half (bottom half) for handwritten text
    handwritten_crop = image[700: height-900, :]
    cv2.imwrite(printed_dir, handwritten_crop)

    print("Image successfully split and saved.")

# %%
import os

folder_path = 'D://Thesis//dataset//Datasets//IAM//data//000//'
handwritten_dir = 'D://Thesis//Mass_Line_Extraction//output_images//printed'
printed_dir = 'D://Thesis//Mass_Line_Extraction//output_images//handwritten'
# List all files in the directory
files = os.listdir(folder_path)
cnt = 10000
# Loop through the files and print the full path
for file in files:
    full_path = os.path.join(folder_path, file)
    seperate_image_section_cropping_handwritten_printed_IAM(full_path, handwritten_dir, printed_dir, cnt)
    cnt = cnt + 1
# Out:
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.
# Image successfully split and saved.

# %% [markdown]
# # Training the Classifier Handwriting vs printed

# %%
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset, random_split
from torchvision import transforms, models
from PIL import Image
import matplotlib.pyplot as plt

# Check device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# Define custom dataset
class LineDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.samples = []
        
        # Label: printed -> 0, handwritten -> 1
        for label, folder in enumerate(['printed', 'handwritten']):
            folder_path = os.path.join(root_dir, folder)
            for img_name in os.listdir(folder_path):
                img_path = os.path.join(folder_path, img_name)
                self.samples.append((img_path, label))
    
    def __len__(self):
        return len(self.samples)
    
    def __getitem__(self, idx):
        img_path, label = self.samples[idx]
        image = Image.open(img_path).convert('RGB')
        if self.transform:
            image = self.transform(image)
        return image, label

# Image transformations
transform = transforms.Compose([
    transforms.Resize((224, 224)),  
    transforms.ToTensor(),          
    transforms.Normalize([0.5, 0.5, 0.5], [0.5, 0.5, 0.5])  
])

# Create full dataset
full_dataset = LineDataset(root_dir='path_to_your_dataset_folder', transform=transform)

# Split into training and validation (80% train, 20% val)
train_size = int(0.8 * len(full_dataset))
val_size = len(full_dataset) - train_size
train_dataset, val_dataset = random_split(full_dataset, [train_size, val_size])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

# Define the model
class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.model = models.resnet18(pretrained=True)
        self.model.fc = nn.Linear(self.model.fc.in_features, 2)  # 2 classes

    def forward(self, x):
        return self.model(x)

model = SimpleCNN().to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# Track losses and accuracies
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

# Training loop
epochs = 10
for epoch in range(epochs):
    model.train()
    running_loss = 0.0
    correct = 0
    total = 0

    for images, labels in train_loader:
        images, labels = images.to(device), labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()
    
    train_loss = running_loss / len(train_loader)
    train_acc = 100. * correct / total
    train_losses.append(train_loss)
    train_accuracies.append(train_acc)

    # Validation
    model.eval()
    val_running_loss = 0.0
    val_correct = 0
    val_total = 0

    with torch.no_grad():
        for images, labels in val_loader:
            images, labels = images.to(device), labels.to(device)

            outputs = model(images)
            loss = criterion(outputs, labels)

            val_running_loss += loss.item()

            _, predicted = outputs.max(1)
            val_total += labels.size(0)
            val_correct += predicted.eq(labels).sum().item()

    val_loss = val_running_loss / len(val_loader)
    val_acc = 100. * val_correct / val_total
    val_losses.append(val_loss)
    val_accuracies.append(val_acc)

    print(f"Epoch [{epoch+1}/{epochs}] Train Loss: {train_loss:.4f} Train Acc: {train_acc:.2f}% | Val Loss: {val_loss:.4f} Val Acc: {val_acc:.2f}%")

# Save model
torch.save(model.state_dict(), 'line_classifier.pth')
print("Training complete and model saved!")

# --------------------------
# Plotting training and validation curves
# --------------------------
epochs_range = range(1, epochs + 1)

plt.figure(figsize=(14, 6))

# Loss
plt.subplot(1, 2, 1)
plt.plot(epochs_range, train_losses, marker='o', label='Train Loss', color='red')
plt.plot(epochs_range, val_losses, marker='o', label='Val Loss', color='orange')
plt.title('Loss Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)

# Accuracy
plt.subplot(1, 2, 2)
plt.plot(epochs_range, train_accuracies, marker='o', label='Train Accuracy', color='blue')
plt.plot(epochs_range, val_accuracies, marker='o', label='Val Accuracy', color='green')
plt.title('Accuracy Curve')
plt.xlabel('Epoch')
plt.ylabel('Accuracy (%)')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()
